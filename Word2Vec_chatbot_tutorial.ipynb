# %% [markdown]
# <a href="https://colab.research.google.com/github/prisa1987/ABudget/blob/master/Word2Vec_chatbot_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %% [markdown]
# Chatbot Tutorial
# ================
# **Author:** `Matthew Inkawhich <https://github.com/MatthewInkawhich>`_

# %% [markdown]
# In this tutorial, we explore a fun and interesting use-case of recurrent
# sequence-to-sequence models. We will train a simple chatbot using movie
# scripts from the `Cornell Movie-Dialogs
# Corpus <https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html>`__.
#
# .. attention:: This example requires PyTorch 1.0 (preview) or later.
#    For installation information visit http://pytorch.org/get-started.
#
# Conversational models are a hot topic in artificial intelligence
# research. Chatbots can be found in a variety of settings, including
# customer service applications and online helpdesks. These bots are often
# powered by retrieval-based models, which output predefined responses to
# questions of certain forms. In a highly restricted domain like a
# company’s IT helpdesk, these models may be sufficient, however, they are
# not robust enough for more general use-cases. Teaching a machine to
# carry out a meaningful conversation with a human in multiple domains is
# a research question that is far from solved. Recently, the deep learning
# boom has allowed for powerful generative models like Google’s `Neural
# Conversational Model <https://arxiv.org/abs/1506.05869>`__, which marks
# a large step towards multi-domain generative conversational models. In
# this tutorial, we will implement this kind of model in PyTorch.
#
# .. figure:: /_static/img/chatbot/bot.png
#    :align: center
#    :alt: bot
#
# .. code:: python
#
#   > hello?
#   bot: hello .
#   > where am I?
#   bot: you re in a hospital .
#   > who are you?
#   bot: i m a lawyer .
#   > how are you doing?
#   bot: i m fine .
#   > are you my friend?
#   bot: no .
#   > you're under arrest
#   bot: i m trying to help you !
#   > i'm just kidding
#   bot: i m sorry .
#   > where are you from?
#   bot: san francisco .
#   > it's time for me to leave
#   bot: i know .
#   > goodbye
#   bot: goodbye .
#
# **Tutorial Highlights**
#
# -  Handle loading and preprocessing of `Cornell Movie-Dialogs
#    Corpus <https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html>`__
#    dataset
# -  Implement a sequence-to-sequence model with `Luong attention
#    mechanism(s) <https://arxiv.org/abs/1508.04025>`__
# -  Jointly train encoder and decoder models using mini-batches
# -  Implement greedy-search decoding module
# -  Interact with trained chatbot
#
# **Acknowledgements**
#
# This tutorial borrows code from the following sources:
#
# 1) Yuan-Kuei Wu’s pytorch-chatbot implementation:
#    https://github.com/ywk991112/pytorch-chatbot
#
# 2) Sean Robertson’s practical-pytorch seq2seq-translation example:
#    https://github.com/spro/practical-pytorch/tree/master/seq2seq-translation
#
# 3) FloydHub’s Cornell Movie Corpus preprocessing code:
#    https://github.com/floydhub/textutil-preprocess-cornell-movie-corpus

# %% [markdown]
# Preparations
# ------------
#
# To start, Download the data ZIP file
# `here <https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html>`__
# and put in a ``data/`` directory under the current directory.
#
# After that, let’s import some necessities.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math


USE_CUDA = torch.cuda.is_available() 
device = torch.device("cuda" if USE_CUDA else "cpu")
print("====> Device :", device)
# Out:
# ====> Device : cuda

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Load & Preprocess Data
# ----------------------
#
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The `Cornell Movie-Dialogs
# Corpus <https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html>`__
# is a rich dataset of movie character dialog:
#
# -  220,579 conversational exchanges between 10,292 pairs of movie
#    characters
# -  9,035 characters from 617 movies
# -  304,713 total utterances
#
# This dataset is large and diverse, and there is a great variation of
# language formality, time periods, sentiment, etc. Our hope is that this
# diversity makes our model robust to many forms of inputs and queries.
#
# First, we’ll take a look at some lines of our datafile to see the
# original format.

# %%
corpus_name = "cornell movie-dialogs corpus"
corpus = os.path.join("/content/drive/My Drive/Colab Notebooks/chatbot/data", corpus_name)
save_dir = os.path.join("/content/drive/My Drive/Colab Notebooks/chatbot/model")
save_evaluation = os.path.join("/content/drive/My Drive/Colab Notebooks/chatbot/evaluation")

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "movie_lines.txt"))
# Out:
# b'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!\n'
# b'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!\n'
# b'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.\n'
# b'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?\n'
# b"L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.\n"
# b'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow\n'
# b"L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.\n"
# b'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No\n'
# b'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?\n'
# b'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?\n'

# %% [markdown]
# Create formatted data file
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Now it is time to use the functions that we defined above to create an
# appropriately formatted data file. Each line of this new file will
# contain a tab-separated *query sentence* and a *response sentence* pair.
#
# The following functions facilitate the parsing of the raw
# *movie_lines.txt* data file.
#
# -  ``loadLines`` splits each line of the file into a dictionary of
#    fields (lineID, characterID, movieID, character, text)
# -  ``loadConversations`` groups fields of lines from ``loadLines`` into
#    conversations based on *movie_conversations.txt*
# -  ``extractSentencePairs`` extracts pairs of sentences from
#    conversations

# %%
# Splits each line of the file into a dictionary of fields
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            lineObj = {}
            for i, field in enumerate(fields):
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines


# Groups fields of lines from `loadLines` into conversations based on *movie_conversations.txt*
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
            lineIds = eval(convObj["utteranceIDs"])
            # Reassemble lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Now we’ll call these functions and create the file. We’ll call it
# *formatted_movie_lines.txt*.

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict, conversations list, and field ids
lines = {}
conversations = []
MOVIE_LINES_FIELDS = ["lineID", "characterID", "movieID", "character", "text"]
MOVIE_CONVERSATIONS_FIELDS = ["character1ID", "character2ID", "movieID", "utteranceIDs"]

# Load lines and process conversations
print("\nProcessing corpus...")
lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)
print("\nLoading conversations...")
conversations = loadConversations(os.path.join(corpus, "movie_conversations.txt"),
                                  lines, MOVIE_CONVERSATIONS_FIELDS)

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter)
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus...
#
# Loading conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b"Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.\tWell, I thought we'd start with pronunciation, if that's okay with you.\r\n"
# b"Well, I thought we'd start with pronunciation, if that's okay with you.\tNot the hacking and gagging and spitting part.  Please.\r\n"
# b"Not the hacking and gagging and spitting part.  Please.\tOkay... then how 'bout we try out some French cuisine.  Saturday?  Night?\r\n"
# b"You're asking me out.  That's so cute. What's your name again?\tForget it.\r\n"
# b"No, no, it's my fault -- we didn't have a proper introduction ---\tCameron.\r\n"
# b"Cameron.\tThe thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\r\n"
# b"The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\tSeems like she could get a date easy enough...\r\n"
# b'Why?\tUnsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\r\n'
# b"Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\tThat's a shame.\r\n"
# b'Gosh, if only we could find Kat a boyfriend...\tLet me see what I can do.\r\n'

# %% [markdown]
# Load and trim data
# ~~~~~~~~~~~~~~~~~~
#
# Our next order of business is to create a vocabulary and load
# query/response sentence pairs into memory.
#
# Note that we are dealing with sequences of **words**, which do not have
# an implicit mapping to a discrete numerical space. Thus, we must create
# one by mapping each unique word that we encounter in our dataset to an
# index value.
#
# For this we define a ``Voc`` class, which keeps a mapping from words to
# indexes, a reverse mapping of indexes to words, a count of each word and
# a total word count. The class provides methods for adding a word to the
# vocabulary (``addWord``), adding all words in a sentence
# (``addSentence``) and trimming infrequently seen words (``trim``). More
# on trimming later.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.word_sentences = []
        self.name = name
        self.words = ["PAD", "SOS", "EOS"]
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def clear(self):
        self.words = []
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {}
        self.num_words = 0  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
            self.words.append(word)
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))
      
        print("keep_words:", keep_words)
        print("len keep_words:", len(keep_words))
        # print("word_sentences:", self.word_sentences)
        # print("len word_sentences", len(self.word_sentences[0]))
        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we can assemble our vocabulary and query/response sentence pairs.
# Before we are ready to use this data, we must perform some
# preprocessing.
#
# First, we must convert the Unicode strings to ASCII using
# ``unicodeToAscii``. Next, we should convert all letters to lowercase and
# trim all non-letter characters except for basic punctuation
# (``normalizeString``). Finally, to aid in training convergence, we will
# filter out sentences with length greater than the ``MAX_LENGTH``
# threshold (``filterPairs``).

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# http://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
# save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)

voc.word_sentence = []
for pair in pairs:
    q = pair[0]
    a = pair[1]
    voc.word_sentences.append(q.split(' '))
    voc.word_sentences.append(a.split(' '))
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64271 sentence pairs
# Counting words...
# Counted words: 18008
#
# pairs:
# ['there .', 'where ?']
# ['you have my word . as a gentleman', 'you re sweet .']
# ['hi .', 'looks like things worked out tonight huh ?']
# ['you know chastity ?', 'i believe we share an art instructor']
# ['have fun tonight ?', 'tons']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['what good stuff ?', 'the real you .']

# %% [markdown]
# Another tactic that is beneficial to achieving faster convergence during
# training is trimming rarely used words out of our vocabulary. Decreasing
# the feature space will also soften the difficulty of the function that
# the model must learn to approximate. We will do this as a two-step
# process:
#
# 1) Trim words used under ``MIN_COUNT`` threshold using the ``voc.trim``
#    function.
#
# 2) Filter out pairs with trimmed words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        
        keep_input = True
        keep_output = True
       
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7823 / 18005 = 0.4345
# keep_words: ['there', '.', 'where', '?', 'you', 'have', 'my', 'word', 'as', 'a', 'gentleman', 're', 'sweet', 'hi', 'looks', 'like', 'things', 'worked', 'out', 'tonight', 'huh', 'know', 'i', 'believe', 'we', 'share', 'an', 'art', 'fun', 'tons', 'well', 'no', 'then', 'that', 's', 'all', 'had', 'to', 'say', 'but', 'always', 'been', 'this', 'selfish', 'do', 'listen', 'crap', 'what', 'good', 'stuff', 'the', 'real', 'fear', 'of', 'wearing', 'wow', 'let', 'go', 'she', 'okay', 'hope', 'so', 'they', '!', 'not', 'did', 'change', 'your', 'hair', 'might', 'wanna', 'think', 'about', 'it', 'who', 'joey', 'great', 'would', 'mind', 'getting', 'me', 'drink', 'cameron', 'more', 'expensive', 'hey', 've', 'nowhere', 'daddy', 'are', 'completely', 'can', 'now', 'in', 'th', 'for', 'month', 'why', 'he', 'was', 'total', 'babe', 'hate', 'looked', 'beautiful', 'last', 'night', 'set', 'up', 'just', 'wanted', 'patrick', 'is', 'doesn', 't', 'want', 'date', 'exactly', 'point', 'and', 'going', 'oh', 'god', 'starting', 'party', 'wear', 'before', 'minute', 'because', 'll', 'scare', 'them', 'away', 'prom', 'kat', 'has', 'new', 'guy', 'tell', 'which', 'dakota', 'from', 'north', 'actually', 'how', 'd', 'kidding', 'people', 'live', 'many', 'were', 'old', 'school', 'thirty', 'two', 'get', 'here', 'couple', 'thousand', 'most', 'evil', 'girl', 'burn', 'perish', 'yeah', 'minor', 'with', 'her', 'bianca', 'sister', 'herself', 'him', 'makes', 'seems', 'on', 'danger', 'number', 'one', 'hates', 'lung', 'cancer', 'issue', 'favorite', 'uncle', 'dead', 'at', 'forty', 'pretty', 'wasn', 'sure', 'ears', 'band', 'playing', 'tomorrow', 'don', 'make', 'man', 'm', 'little', 'busy', 'off', 'whole', 'thing', 'talking', 'makin', 'any', 'kissed', 'worst', 'ya', 'goin', 'leave', 'alone', 'said', 'need', 'money', 'take', 'when', 'shell', 'fifty', 'expect', 'price', 'hundred', 'bucks', 'forget', 'time', 'deal', 'act', 'human', 'lost', 'nope', 'came', 'by', 'chat', 'hear', 'helpin', 'verona', 'uh', 'friend', 'random', 'look', 'block', 'e', 'slit', 'william', 'didn', 'even', 'high', 'never', 'proven', 'neither', 'his', 'work', 'cares', 'favor', 'seen', 'asked', 'meet', 'mean', 'doin', 'pig', 'yourself', 'pick', 'friday', 'right', 'covered', 'vomit', 'seven', 'excuse', 'isn', 'funny', 'only', 'fine', 'lie', 'down', 'awhile', 'doing', 'told', 'care', 'if', 'die', 'thought', 'above', 'wake', 'jail', 'maybe', 'weren', 'ask', 'should', 'start', 'father', 'wouldn', 'approve', 'gettin', 'heard', 'poetry', 'reading', 'pleasant', 'effect', 'other', 'than', 'nothing', 'c', 'mon', 'bad', 'try', 'lookin', 'angle', 'put', 'foot', 'stayin', 'soft', 'side', 'knew', 'acting', 'way', 'yes', 'something', 'screwed', 'disappointed', 'state', 'duck', 'career', 'true', 'else', 'knows', 'request', 'or', 'command', 'won', 'grandmother', 'insurance', 'does', 'cover', 'pms', 'punishing', 'agree', 'making', 'decisions', 'matter', 'parts', 'tired', 'breathing', 'cool', 'pictures', 'fan', 'guess', 'too', 'enough', 'ever', 'club', 'skunk', 'still', 'pissed', 'love', 'thy', 'force', 'see', 'next', 'week', 'microwave', 'anyone', 'cry', 'today', 'helping', 'honey', 'happened', 'daughters', 'went', 'anything', 'absolutely', 'devil', 'child', 'crazy', 'life', 'others', 'follow', 'could', 'be', 'gone', 'years', 'thank', 'usually', 'stay', 'us', 'am', 'inside', 'may', 'whom', 'colon', 'de', 'remember', 'letters', 'appointment', 'west', 'explore', 'feeling', 'ambitious', 'defend', 'come', 'speak', 'first', 'chief', 'says', 'thousands', 'bring', 'also', 'medicine', 'will', 'help', 'manage', 'jew', 'christ', 'passion', 'cannot', 'control', 'lies', 'nomine', 'et', 'forgive', 'sinned', 'believed', 'give', 'suppose', 'both', 'men', 'older', 'worlds', 'create', 'ocean', 'granada', 'ignore', 'verdict', 'surely', 'freely', 'show', 'otherwise', 'raise', 'wheel', 'without', 'horse', 'read', 'twenty', 'eight', 'immediately', 'six', 'days', 'ago', 'must', 'mad', 'land', 'decide', 'sanchez', 'majesty', 'suggest', 'replaced', 'tolerate', 'afr ...
# len keep_words: 7823
# Trimmed from 64271 pairs to 53165, 0.8272 of total

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot


# train model
voc.word_sentences.insert(0,["PAD"])
voc.word_sentences.insert(1,["EOS"])
voc.word_sentences.insert(2,["SOS"])

voc.word_sentences.insert(3,["PAD"])
voc.word_sentences.insert(4,["EOS"])
voc.word_sentences.insert(5,["SOS"])

voc.word_sentences.insert(6,["PAD"])
voc.word_sentences.insert(7,["EOS"])
voc.word_sentences.insert(8,["SOS"])

print("voc.word_sentences: ", voc.word_sentences[:20])
print("voc.word_sentences: ", len(voc.word_sentences))
model = Word2Vec(voc.word_sentences, size=500, min_count=3, workers=4)
weights = torch.FloatTensor(model.wv.vectors)
words = list(model.wv.vocab)
# voc.clear()

for word in model.wv.vocab:
  # print(word)
  voc.addWord(word)

# pairs = trimRareWords(voc, pairs, MIN_COUNT)
print(voc.words)
print(len(voc.words))
print(model.wv.vectors)
print(model.wv.vectors.shape)
print("words ", voc.num_words)
# Out:
# voc.word_sentences:  [['PAD'], ['EOS'], ['SOS'], ['PAD'], ['EOS'], ['SOS'], ['PAD'], ['EOS'], ['SOS'], ['there', '.'], ['where', '?'], ['you', 'have', 'my', 'word', '.', 'as', 'a', 'gentleman'], ['you', 're', 'sweet', '.'], ['hi', '.'], ['looks', 'like', 'things', 'worked', 'out', 'tonight', 'huh', '?'], ['you', 'know', 'chastity', '?'], ['i', 'believe', 'we', 'share', 'an', 'art', 'instructor'], ['have', 'fun', 'tonight', '?'], ['tons'], ['well', 'no', '.', '.', '.']]
# voc.word_sentences:  128551
# ['PAD', 'SOS', 'EOS', 'there', '.', 'where', '?', 'you', 'have', 'my', 'word', 'as', 'a', 'gentleman', 're', 'sweet', 'hi', 'looks', 'like', 'things', 'worked', 'out', 'tonight', 'huh', 'know', 'chastity', 'i', 'believe', 'we', 'share', 'an', 'art', 'instructor', 'fun', 'tons', 'well', 'no', 'then', 'that', 's', 'all', 'had', 'to', 'say', 'but', 'always', 'been', 'this', 'selfish', 'do', 'listen', 'crap', 'what', 'good', 'stuff', 'the', 'real', 'fear', 'of', 'wearing', 'pastels', 'wow', 'let', 'go', 'she', 'okay', 'hope', 'so', 'they', '!', 'not', 'did', 'change', 'your', 'hair', 'might', 'wanna', 'think', 'about', 'it', 'who', 'joey', 'great', 'would', 'mind', 'getting', 'me', 'drink', 'cameron', 'more', 'expensive', 'hey', 'cheeks', 've', 'nowhere', 'daddy', 'are', 'completely', 'unbalanced', 'can', 'now', 'in', 'th', 'for', 'month', 'why', 'he', 'was', 'total', 'babe', 'hate', 'looked', 'beautiful', 'last', 'night', 'set', 'up', 'just', 'wanted', 'patrick', 'is', 'perm', 'doesn', 't', 'want', 'date', 'exactly', 'point', 'and', 'going', 'oh', 'god', 'starting', 'party', 'wear', 'belly', 'before', 'minute', 'because', 'll', 'scare', 'them', 'away', 'prom', 'kat', 'has', 'new', 'guy', 'tell', 'which', 'dakota', 'from', 'north', 'actually', 'how', 'd', 'kidding', 'people', 'live', 'many', 'were', 'old', 'school', 'thirty', 'two', 'get', 'here', 'couple', 'thousand', 'most', 'evil', 'girl', 'burn', 'pine', 'perish', 'yeah', 'minor', 'encounter', 'with', 'shrew', 'her', 'bianca', 'sister', 'mewling', 'rampalian', 'wretch', 'herself', 'him', 'makes', 'seems', 'thrives', 'on', 'danger', 'number', 'one', 'hates', 'smokers', 'lung', 'cancer', 'issue', 'favorite', 'uncle', 'dead', 'at', 'forty', 'pretty', 'wasn', 'sure', 'assail', 'ears', 'band', 'gigglepuss', 'playing', 'tomorrow', 'don', 'make', 'man', 'm', 'little', 'busy', 'off', 'whole', 'thing', 'talking', 'partial', 'makin', 'any', 'headway', 'kissed', 'worst', 'ya', 'goin', 'leave', 'alone', 'said', 'need', 'money', 'take', 'when', 'shell', 'fifty', 'expect', 'results', 'upped', 'price', 'hundred', 'bucks', 'forget', 'time', 'deal', 'act', 'human', 'lost', 'nope', 'came', 'by', 'chat', 'hear', 'helpin', 'verona', 'uh', 'friend', 'random', 'skid', 'look', 'block', 'e', 'attempted', 'slit', 'william', 'didn', 'even', 'high', 'never', 'proven', 'neither', 'his', 'heterosexuality', 'work', 'cares', 'favor', 'backfired', 'seen', 'asked', 'meet', 'mean', 'wo', 'doin', 'sweating', 'pig', 'yourself', 'pick', 'friday', 'right', 'covered', 'vomit', 'seven', 'excuse', 'isn', 'raincoats', 'funny', 'only', 'fine', 'lie', 'down', 'awhile', 'doing', 'told', 'care', 'if', 'die', 'dorsey', 'thought', 'above', 'wake', 'jail', 'maybe', 'weren', 'ask', 'should', 'start', 'father', 'wouldn', 'approve', 'gettin', 'heard', 'poetry', 'reading', 'pleasant', 'wholesome', 'unwelcome', 'effect', 'other', 'than', 'upchuck', 'reflex', 'nothing', 'c', 'mon', 'bad', 'try', 'lookin', 'angle', 'put', 'foot', 'stayin', 'soft', 'side', 'knew', 'acting', 'way', 'yes', 'something', 'screwed', 'disappointed', 'state', 'trooper', 'fallacy', 'duck', 'hearsay', 'porn', 'career', 'true', 'peas', 'else', 'knows', 'request', 'or', 'command', 'won', 'grandmother', 'insurance', 'does', 'cover', 'pms', 'seizure', 'punishing', 'agree', 'making', 'decisions', 'parent', 'matter', 'parts', 'tired', 'breathing', 'cool', 'pictures', 'fan', 'guess', 'macbeth', 'too', 'enough', 'ever', 'club', 'skunk', 'still', 'pissed', 'love', 'renew', 'thy', 'force', 'demented', 'see', 'next', 'week', 'microwave', 'anyone', 'cry', 'today', 'tumescent', 'helping', 'honey', 'happened', 'daughters', 'went', 'anything', 'absolutely', 'devil', 'child', 'crazy', 'life', 'others', 'follow', 'could', 'be', 'gone', 'years', 'thank', 'beatrix', 'usually', 'stay', 'us', 'am', 'inside', 'may', 'whom', 'bartolome', 'giacomo', 'colon', 'alonso', 'de', 'bobadilla', 'remember', 'letters', 'appointment', 'viceroy', 'west', 'indies', 'explore', 'mainland', 'feeli ...
# 25834
# [[ 5.3652231e-02 -1.9262357e-01  2.0896997e-01 ... -2.3428978e-02
#    2.8737479e-01  5.1262777e-02]
#  [-1.1640818e-01  1.3467546e-01  3.2992929e-01 ... -3.2222936e-01
#    1.3052340e-01  3.5387322e-01]
#  [ 1.7950666e-01  2.8027004e-01 -9.6718535e-02 ... -6.5597397e-01
#    1.2830538e-01  8.2071656e-01]
#  ...
#  [-1.1207715e-03 -6.6736963e-04  7.1389263e-04 ... -5.3042517e-04
#   -1.3913771e-03 -3.6694373e-03]
#  [ 1.6427504e-02  2.1563132e-05  3.5156948e-03 ... -1.2044057e-02
#   -2.3641200e-03  1.1436560e-02]
#  [ 1.0561892e-03 -4.2466489e-03  7.6326123e-03 ... -1.2355429e-04
#   -1.2851362e-03  5.3229006e-03]]
# (7826, 500)
# words  7829

# %%
print(model.most_similar("dad"))
# Out:
# [('mom', 0.9551358819007874), ('boss', 0.8802250623703003), ('baby', 0.8756309151649475), ('daddy', 0.8551047444343567), ('jack', 0.8537517786026001), ('frank', 0.851838231086731), ('nick', 0.8496579527854919), ('brother', 0.8378266096115112), ('son', 0.8304013609886169), ('honey', 0.8297032117843628)]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# Prepare Data for Models
# -----------------------
#
# Although we have spent a great effort preparing and massaging our data
# into a nice vocabulary object and list of sentence pairs, our models
# will ultimately expect numerical torch tensors as inputs. One way to
# prepare the processed data for the models can be found in the `seq2seq
# translation
# tutorial <https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html>`__.
# In that tutorial, we use a batch size of 1, meaning that all we have to
# do is convert the words in our sentence pairs to their corresponding
# indexes from the vocabulary and feed this to the models.
#
# However, if you’re interested in speeding up training and/or would like
# to leverage GPU parallelization capabilities, you will need to train
# with mini-batches.
#
# Using mini-batches also means that we must be mindful of the variation
# of sentence length in our batches. To accomodate sentences of different
# sizes in the same batch, we will make our batched input tensor of shape
# *(max_length, batch_size)*, where sentences shorter than the
# *max_length* are zero padded after an *EOS_token*.
#
# If we simply convert our English sentences to tensors by converting
# words to their indexes(\ ``indexesFromSentence``) and zero-pad, our
# tensor would have shape *(batch_size, max_length)* and indexing the
# first dimension would return a full sequence across all time-steps.
# However, we need to be able to index our batch along time, and across
# all sequences in the batch. Therefore, we transpose our input batch
# shape to *(max_length, batch_size)*, so that indexing across the first
# dimension returns a time step across all sentences in the batch. We
# handle this transpose implicitly in the ``zeroPadding`` function.
#
# .. figure:: /_static/img/chatbot/seq2seq_batches.png
#    :align: center
#    :alt: batches
#
# The ``inputVar`` function handles the process of converting sentences to
# tensor, ultimately creating a correctly shaped zero-padded tensor. It
# also returns a tensor of ``lengths`` for each of the sequences in the
# batch which will be passed to our decoder later.
#
# The ``outputVar`` function performs a similar function to ``inputVar``,
# but instead of returning a ``lengths`` tensor, it returns a binary mask
# tensor and a maximum target sentence length. The binary mask tensor has
# the same shape as the output target tensor, but every element that is a
# *PAD_token* is 0 and all others are 1.
#
# ``batch2TrainData`` simply takes a bunch of pairs and returns the input
# and target tensors using the aforementioned functions.

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]

def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[1227, 1762, 7493,  167,   50],
#         [  76,  197,    4,    4,    6],
#         [1227,  117,   25,    2,    2],
#         [  76,   59,  197,    0,    0],
#         [   4,  134,  117,    0,    0],
#         [   4,  282,   81,    0,    0],
#         [   4,    4,    4,    0,    0],
#         [   2,    2,    2,    0,    0]])
# lengths: tensor([8, 8, 8, 3, 3])
# target_variable: tensor([[  50,  158,  266,  115,   25],
#         [  37,   96, 1172,    3,   74],
#         [ 774,    4,    4,   12,   61],
#         [   6,    2,    2,  568,  215],
#         [   2,    0,    0, 1157,  170],
#         [   0,    0,    0,  188,  706],
#         [   0,    0,    0,    7,  102],
#         [   0,    0,    0,    6, 5536],
#         [   0,    0,    0,    2,    4],
#         [   0,    0,    0,    0,    2]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True, False, False,  True,  True],
#         [False, False, False,  True,  True],
#         [False, False, False,  True,  True],
#         [False, False, False,  True,  True],
#         [False, False, False,  True,  True],
#         [False, False, False, False,  True]])
# max_target_len: 10

# %% [markdown]
# Define Models
# -------------
#
# Seq2Seq Model
# ~~~~~~~~~~~~~
#
# The brains of our chatbot is a sequence-to-sequence (seq2seq) model. The
# goal of a seq2seq model is to take a variable-length sequence as an
# input, and return a variable-length sequence as an output using a
# fixed-sized model.
#
# `Sutskever et al. <https://arxiv.org/abs/1409.3215>`__ discovered that
# by using two separate recurrent neural nets together, we can accomplish
# this task. One RNN acts as an **encoder**, which encodes a variable
# length input sequence to a fixed-length context vector. In theory, this
# context vector (the final hidden layer of the RNN) will contain semantic
# information about the query sentence that is input to the bot. The
# second RNN is a **decoder**, which takes an input word and the context
# vector, and returns a guess for the next word in the sequence and a
# hidden state to use in the next iteration.
#
# .. figure:: /_static/img/chatbot/seq2seq_ts.png
#    :align: center
#    :alt: model
#
# Image source:
# https://jeddy92.github.io/JEddy92.github.io/ts_seq2seq_intro/

# %% [markdown]
# Encoder
# ~~~~~~~
#
# The encoder RNN iterates through the input sentence one token
# (e.g. word) at a time, at each time step outputting an “output” vector
# and a “hidden state” vector. The hidden state vector is then passed to
# the next time step, while the output vector is recorded. The encoder
# transforms the context it saw at each point in the sequence into a set
# of points in a high-dimensional space, which the decoder will use to
# generate a meaningful output for the given task.
#
# At the heart of our encoder is a multi-layered Gated Recurrent Unit,
# invented by `Cho et al. <https://arxiv.org/pdf/1406.1078v3.pdf>`__ in
# 2014. We will use a bidirectional variant of the GRU, meaning that there
# are essentially two independent RNNs: one that is fed the input sequence
# in normal sequential order, and one that is fed the input sequence in
# reverse order. The outputs of each network are summed at each time step.
# Using a bidirectional GRU will give us the advantage of encoding both
# past and future context.
#
# Bidirectional RNN:
#
# .. figure:: /_static/img/chatbot/RNN-bidirectional.png
#    :width: 70%
#    :align: center
#    :alt: rnn_bidir
#
# Image source: http://colah.github.io/posts/2015-09-NN-Types-FP/
#
# Note that an ``embedding`` layer is used to encode our word indices in
# an arbitrarily sized feature space. For our models, this layer will map
# each word to a feature space of size *hidden_size*. When trained, these
# values should encode semantic similarity between similar meaning words.
#
# Finally, if passing a padded batch of sequences to an RNN module, we
# must pack and unpack padding around the RNN pass using
# ``torch.nn.utils.rnn.pack_padded_sequence`` and
# ``torch.nn.utils.rnn.pad_packed_sequence`` respectively.
#
# **Computation Graph:**
#
#    1) Convert word indexes to embeddings.
#    2) Pack padded batch of sequences for RNN module.
#    3) Forward pass through GRU.
#    4) Unpack padding.
#    5) Sum bidirectional GRU outputs.
#    6) Return output and final hidden state.
#
# **Inputs:**
#
# -  ``input_seq``: batch of input sentences; shape=\ *(max_length,
#    batch_size)*
# -  ``input_lengths``: list of sentence lengths corresponding to each
#    sentence in the batch; shape=\ *(batch_size)*
# -  ``hidden``: hidden state; shape=\ *(n_layers x num_directions,
#    batch_size, hidden_size)*
#
# **Outputs:**
#
# -  ``outputs``: output features from the last hidden layer of the GRU
#    (sum of bidirectional outputs); shape=\ *(max_length, batch_size,
#    hidden_size)*
# -  ``hidden``: updated hidden state from GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = torch.nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = torch.nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Decoder
# ~~~~~~~
#
# The decoder RNN generates the response sentence in a token-by-token
# fashion. It uses the encoder’s context vectors, and internal hidden
# states to generate the next word in the sequence. It continues
# generating words until it outputs an *EOS_token*, representing the end
# of the sentence. A common problem with a vanilla seq2seq decoder is that
# if we rely soley on the context vector to encode the entire input
# sequence’s meaning, it is likely that we will have information loss.
# This is especially the case when dealing with long input sequences,
# greatly limiting the capability of our decoder.
#
# To combat this, `Bahdanau et al. <https://arxiv.org/abs/1409.0473>`__
# created an “attention mechanism” that allows the decoder to pay
# attention to certain parts of the input sequence, rather than using the
# entire fixed context at every step.
#
# At a high level, attention is calculated using the decoder’s current
# hidden state and the encoder’s outputs. The output attention weights
# have the same shape as the input sequence, allowing us to multiply them
# by the encoder outputs, giving us a weighted sum which indicates the
# parts of encoder output to pay attention to. `Sean
# Robertson’s <https://github.com/spro>`__ figure describes this very
# well:
#
# .. figure:: /_static/img/chatbot/attn2.png
#    :align: center
#    :alt: attn2
#
# `Luong et al. <https://arxiv.org/abs/1508.04025>`__ improved upon
# Bahdanau et al.’s groundwork by creating “Global attention”. The key
# difference is that with “Global attention”, we consider all of the
# encoder’s hidden states, as opposed to Bahdanau et al.’s “Local
# attention”, which only considers the encoder’s hidden state from the
# current time step. Another difference is that with “Global attention”,
# we calculate attention weights, or energies, using the hidden state of
# the decoder from the current time step only. Bahdanau et al.’s attention
# calculation requires knowledge of the decoder’s state from the previous
# time step. Also, Luong et al. provides various methods to calculate the
# attention energies between the encoder output and decoder output which
# are called “score functions”:
#
# .. figure:: /_static/img/chatbot/scores.png
#    :width: 60%
#    :align: center
#    :alt: scores
#
# where $h_t$ = current target decoder state and $\bar{h}_s$ =
# all encoder states.
#
# Overall, the Global attention mechanism can be summarized by the
# following figure. Note that we will implement the “Attention Layer” as a
# separate ``nn.Module`` called ``Attn``. The output of this module is a
# softmax normalized weights tensor of shape *(batch_size, 1,
# max_length)*.
#
# .. figure:: /_static/img/chatbot/global_attn.png
#    :align: center
#    :width: 60%
#    :alt: global_attn

# %%
# Luong attention layer
class Attn(torch.nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = torch.nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = torch.nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = torch.nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %% [markdown]
# Now that we have defined our attention submodule, we can implement the
# actual decoder model. For the decoder, we will manually feed our batch
# one time step at a time. This means that our embedded word tensor and
# GRU output will both have shape *(1, batch_size, hidden_size)*.
#
# **Computation Graph:**
#
#    1) Get embedding of current input word.
#    2) Forward through unidirectional GRU.
#    3) Calculate attention weights from the current GRU output from (2).
#    4) Multiply attention weights to encoder outputs to get new "weighted sum" context vector.
#    5) Concatenate weighted context vector and GRU output using Luong eq. 5.
#    6) Predict next word using Luong eq. 6 (without softmax).
#    7) Return output and final hidden state.
#
# **Inputs:**
#
# -  ``input_step``: one time step (one word) of input sequence batch;
#    shape=\ *(1, batch_size)*
# -  ``last_hidden``: final hidden layer of GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*
# -  ``encoder_outputs``: encoder model’s output; shape=\ *(max_length,
#    batch_size, hidden_size)*
#
# **Outputs:**
#
# -  ``output``: softmax normalized tensor giving probabilities of each
#    word being the correct next word in the decoded sequence;
#    shape=\ *(batch_size, voc.num_words)*
# -  ``hidden``: final hidden state of GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# Define Training Procedure
# -------------------------
#
# Masked loss
# ~~~~~~~~~~~
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# ``maskNLLLoss`` to calculate our loss based on our decoder’s output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# Single training iteration
# ~~~~~~~~~~~~~~~~~~~~~~~~~
#
# The ``train`` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -  The first trick is using **teacher forcing**. This means that at some
#    probability, set by ``teacher_forcing_ratio``, we use the current
#    target word as the decoder’s next input rather than using the
#    decoder’s current guess. This technique acts as training wheels for
#    the decoder, aiding in more efficient training. However, teacher
#    forcing can lead to model instability during inference, as the
#    decoder may not have a sufficient chance to truly craft its own
#    output sequences during training. Thus, we must be mindful of how we
#    are setting the ``teacher_forcing_ratio``, and not be fooled by fast
#    convergence.
#
# -  The second trick that we implement is **gradient clipping**. This is
#    a commonly used technique for countering the “exploding gradient”
#    problem. In essence, by clipping or thresholding gradients to a
#    maximum value, we prevent the gradients from growing exponentially
#    and either overflow (NaN), or overshoot steep cliffs in the cost
#    function.
#
# .. figure:: /_static/img/chatbot/grad_clip.png
#    :align: center
#    :width: 60%
#    :alt: grad_clip
#
# Image source: Goodfellow et al. *Deep Learning*. 2016. http://www.deeplearningbook.org/
#
# **Sequence of Operations:**
#
#    1) Forward pass entire input batch through encoder.
#    2) Initialize decoder inputs as SOS_token, and hidden state as the encoder's final hidden state.
#    3) Forward input batch sequence through decoder one time step at a time.
#    4) If teacher forcing: set next decoder input as the current target; else: set next decoder input as current decoder output.
#    5) Calculate and accumulate loss.
#    6) Perform backpropagation.
#    7) Clip gradients.
#    8) Update encoder and decoder model parameters.
#
#
# .. Note ::
#
#   PyTorch’s RNN modules (``RNN``, ``LSTM``, ``GRU``) can be used like any
#   other non-recurrent layers by simply passing them the entire input
#   sequence (or batch of sequences). We use the ``GRU`` layer like this in
#   the ``encoder``. The reality is that under the hood, there is an
#   iterative process looping over each time step calculating hidden states.
#   Alternatively, you ran run these modules one time-step at a time. In
#   this case, we manually loop over the sequences during the training
#   process like we must do for the ``decoder`` model. As long as you
#   maintain the correct conceptual model of these modules, implementing
#   sequential models can be very straightforward.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    lengths = lengths.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = torch.nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = torch.nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# Training iterations
# ~~~~~~~~~~~~~~~~~~~
#
# It is finally time to tie the full training procedure together with the
# data. The ``trainIters`` function is responsible for running
# ``n_iterations`` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the ``train`` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder state_dicts (parameters), the
# optimizers’ state_dicts, the loss, the iteration, etc. Saving the model
# in this way will give us the ultimate flexibility with the checkpoint.
# After loading a checkpoint, we will be able to use the model parameters
# to run inference, or we can continue training right where we left off.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# Define Evaluation
# -----------------
#
# After training a model, we want to be able to talk to the bot ourselves.
# First, we must define how we want the model to decode the encoded input.
#
# Greedy decoding
# ~~~~~~~~~~~~~~~
#
# Greedy decoding is the decoding method that we use during training when
# we are **NOT** using teacher forcing. In other words, for each time
# step, we simply choose the word from ``decoder_output`` with the highest
# softmax value. This decoding method is optimal on a single time-step
# level.
#
# To facilite the greedy decoding operation, we define a
# ``GreedySearchDecoder`` class. When run, an object of this class takes
# an input sequence (``input_seq``) of shape *(input_seq length, 1)*, a
# scalar input length (``input_length``) tensor, and a ``max_length`` to
# bound the response sentence length. The input sentence is evaluated
# using the following computational graph:
#
# **Computation Graph:**
#
#    1) Forward input through encoder model.
#    2) Prepare encoder's final hidden layer to be first hidden input to the decoder.
#    3) Initialize decoder's first input as SOS_token.
#    4) Initialize tensors to append decoded words to.
#    5) Iteratively decode one word token at a time:
#        a) Forward pass through decoder.
#        b) Obtain most likely word token and its softmax score.
#        c) Record token and score.
#        d) Prepare current token to be next decoder input.
#    6) Return collections of word tokens and scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# Evaluate my text
# ~~~~~~~~~~~~~~~~
#
# Now that we have our decoding method defined, we can write functions for
# evaluating a string input sentence. The ``evaluate`` function manages
# the low-level process of handling the input sentence. We first format
# the sentence as an input batch of word indexes with *batch_size==1*. We
# do this by converting the words of the sentence to their corresponding
# indexes, and transposing the dimensions to prepare the tensor for our
# models. We also create a ``lengths`` tensor which contains the length of
# our input sentence. In this case, ``lengths`` is scalar because we are
# only evaluating one sentence at a time (batch_size==1). Next, we obtain
# the decoded response sentence tensor using our ``GreedySearchDecoder``
# object (``searcher``). Finally, we convert the response’s indexes to
# words and return the list of decoded words.
#
# ``evaluateInput`` acts as the user interface for our chatbot. When
# called, an input text field will spawn in which we can enter our query
# sentence. After typing our input sentence and pressing *Enter*, our text
# is normalized in the same way as our training data, and is ultimately
# fed to the ``evaluate`` function to obtain a decoded output sentence. We
# loop this process, so we can keep chatting with our bot until we enter
# either “q” or “quit”.
#
# Finally, if a sentence is entered that contains a word that is not in
# the vocabulary, we handle this gracefully by printing an error message
# and prompting the user to enter another sentence.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to(device)
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# Run Model
# ---------
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.

# %%
# Configure models
model_name = 'word2Vec'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
loadFilename = os.path.join(save_dir, model_name, corpus_name,
                           '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
                           '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(weights.shape[0], hidden_size)
embedding.weight.data.copy_(weights)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, weights.shape[0], decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Run Training
# ~~~~~~~~~~~~
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the ``trainIters`` function to run our training
# iterations.

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 7000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4001; Percent complete: 57.2%; Average loss: 2.6653
# Iteration: 4002; Percent complete: 57.2%; Average loss: 2.5000
# Iteration: 4003; Percent complete: 57.2%; Average loss: 2.3301
# Iteration: 4004; Percent complete: 57.2%; Average loss: 2.5499
# Iteration: 4005; Percent complete: 57.2%; Average loss: 2.5208
# Iteration: 4006; Percent complete: 57.2%; Average loss: 2.5741
# Iteration: 4007; Percent complete: 57.2%; Average loss: 2.6089
# Iteration: 4008; Percent complete: 57.3%; Average loss: 2.7751
# Iteration: 4009; Percent complete: 57.3%; Average loss: 2.4491
# Iteration: 4010; Percent complete: 57.3%; Average loss: 2.3798
# Iteration: 4011; Percent complete: 57.3%; Average loss: 2.5358
# Iteration: 4012; Percent complete: 57.3%; Average loss: 2.6139
# Iteration: 4013; Percent complete: 57.3%; Average loss: 2.6546
# Iteration: 4014; Percent complete: 57.3%; Average loss: 2.4805
# Iteration: 4015; Percent complete: 57.4%; Average loss: 2.3797
# Iteration: 4016; Percent complete: 57.4%; Average loss: 2.1802
# Iteration: 4017; Percent complete: 57.4%; Average loss: 2.4407
# Iteration: 4018; Percent complete: 57.4%; Average loss: 2.4191
# Iteration: 4019; Percent complete: 57.4%; Average loss: 2.5721
# Iteration: 4020; Percent complete: 57.4%; Average loss: 2.4588
# Iteration: 4021; Percent complete: 57.4%; Average loss: 2.6512
# Iteration: 4022; Percent complete: 57.5%; Average loss: 2.5184
# Iteration: 4023; Percent complete: 57.5%; Average loss: 2.6508
# Iteration: 4024; Percent complete: 57.5%; Average loss: 2.3709
# Iteration: 4025; Percent complete: 57.5%; Average loss: 2.4072
# Iteration: 4026; Percent complete: 57.5%; Average loss: 2.2693
# Iteration: 4027; Percent complete: 57.5%; Average loss: 2.3962
# Iteration: 4028; Percent complete: 57.5%; Average loss: 2.3468
# Iteration: 4029; Percent complete: 57.6%; Average loss: 2.4472
# Iteration: 4030; Percent complete: 57.6%; Average loss: 2.3529
# Iteration: 4031; Percent complete: 57.6%; Average loss: 2.6576
# Iteration: 4032; Percent complete: 57.6%; Average loss: 2.3656
# Iteration: 4033; Percent complete: 57.6%; Average loss: 2.3742
# Iteration: 4034; Percent complete: 57.6%; Average loss: 2.5541
# Iteration: 4035; Percent complete: 57.6%; Average loss: 2.2982
# Iteration: 4036; Percent complete: 57.7%; Average loss: 2.5649
# Iteration: 4037; Percent complete: 57.7%; Average loss: 2.2371
# Iteration: 4038; Percent complete: 57.7%; Average loss: 2.4967
# Iteration: 4039; Percent complete: 57.7%; Average loss: 2.4321
# Iteration: 4040; Percent complete: 57.7%; Average loss: 2.4515
# Iteration: 4041; Percent complete: 57.7%; Average loss: 2.4036
# Iteration: 4042; Percent complete: 57.7%; Average loss: 2.2772
# Iteration: 4043; Percent complete: 57.8%; Average loss: 2.5658
# Iteration: 4044; Percent complete: 57.8%; Average loss: 2.5866
# Iteration: 4045; Percent complete: 57.8%; Average loss: 2.5346
# Iteration: 4046; Percent complete: 57.8%; Average loss: 2.5784
# Iteration: 4047; Percent complete: 57.8%; Average loss: 2.2932
# Iteration: 4048; Percent complete: 57.8%; Average loss: 2.4693
# Iteration: 4049; Percent complete: 57.8%; Average loss: 2.4507
# Iteration: 4050; Percent complete: 57.9%; Average loss: 2.4935
# Iteration: 4051; Percent complete: 57.9%; Average loss: 2.4137
# Iteration: 4052; Percent complete: 57.9%; Average loss: 2.4594
# Iteration: 4053; Percent complete: 57.9%; Average loss: 2.3377
# Iteration: 4054; Percent complete: 57.9%; Average loss: 2.4682
# Iteration: 4055; Percent complete: 57.9%; Average loss: 2.4843
# Iteration: 4056; Percent complete: 57.9%; Average loss: 2.5792
# Iteration: 4057; Percent complete: 58.0%; Average loss: 2.6451
# Iteration: 4058; Percent complete: 58.0%; Average loss: 2.3480
# Iteration: 4059; Percent complete: 58.0%; Average loss: 2.3253
# Iteration: 4060; Percent complete: 58.0%; Average loss: 2.4187
# Iteration: 4061; Percent complete: 58.0%; Average loss: 2.6063
# Iteration: 4062; Percent complete: 58.0%; Average loss: 2.4568
# Iteration: 4063; Percent complete: 58.0%; Average loss: 2.5598
# Iteration: 4064; Percent complete: 58.1%; Average loss: 2.4842
# Iteration: 4065; Percent complete: 58.1%; Average loss: 2.5005
# Iteration: 4066; Percent complete: 58.1%; Average loss: 2.3182
# Iteration: 4067; Percent complete: 58.1%; Average loss: 2.6885
# Iteration: 4068; Percent complete: 58.1%; Average loss: 2.5462
# Iteration: 4069; Percent complete: 58.1%; Average loss: 2.3873
# Iteration: 4070; Percent complete: 58.1%; Average loss: 2.5162
# Iteration: 4071; Percent complete: 58.2%; Average loss: 2.1125
# Iteration: 4072; Percent complete: 58.2%; Average loss: 2.5284
# Iteration: 4073; Percent complete: 58.2%; Average loss: 2.4482
# Iteration: 4074; Percent complete: 58.2%; Average loss: 2.3557
# Iteration: 4075; Percent complete: 58.2%; Average loss: 2.4145
# Iteration: 4076; Percent complete: 58.2%; Average loss: 2.4841
# Iteration: 4077; Percent complete: 58.2%; Average loss: 2.6455
# Iteration: 4078; Percent complete: 58.3%; Average loss: 2.2504
# Iteration: 4079; Percent complete: 58.3%; Average loss: 2.5069
# Iteration: 4080; Percent complete: 58.3%; Average loss: 2.4778
# Iteration: 4081; Percent complete: 58.3%; Average loss: 2.3719
# Iteration: 4082; Percent complete: 58.3%; Average loss: 2.4999
# Iteration: 4083; Percent complete: 58.3%; Average loss: 2.6530
# Iteration: 4084; Percent complete: 58.3%; Average loss: 2.4254
# Iteration: 4085; Percent complete: 58.4%; Average loss: 2.5722
# Iteration: 4086; Percent complete: 58.4%; Average loss: 2.5085
# Iteration: 4087; Percent complete: 58.4%; Average loss: 2.3453
# Iteration: 4088; Percent complete: 58.4%; Average loss: 2.4157
# Iteration: 4089; Percent complete: 58.4%; Average loss: 2.5779
# Iteration: 4090; Percent complete: 58.4%; Average loss: 2.2440
# Iteration: 4091; Percent complete: 58.4%; Average loss: 2.5899
# Iteration: 4092; Percent complete: 58.5%; Average loss: 2.4768
# Iteration: 4093; Percent complete: 58.5%; Average loss: 2.2226
# Iteration: 4094; Percent complete: 58.5%; Average loss: 2.3345
# Iteration: 4095; Percent complete: 58.5%; Average loss: 2.2119
# Iteration: 4096; Percent complete: 58.5%; Average loss: 2.4802
# Iteration: 4097; Percent complete: 58.5%; Average loss: 2.2830
# Iteration: 4098; Percent complete: 58.5%; Average loss: 2.4871
# Iteration: 4099; Percent complete: 58.6%; Average loss: 2.2775
# Iteration: 4100; Percent complete: 58.6%; Average loss: 2.5321
# Iteration: 4101; Percent complete: 58.6%; Average loss: 2.4944
# Iteration: 4102; Percent complete: 58.6%; Average loss: 2.3883
# Iteration: 4103; Percent complete: 58.6%; Average loss: 2.5373
# Iteration: 4104; Percent complete: 58.6%; Average loss: 2.4024
# Iteration: 4105; Percent complete: 58.6%; Average loss: 2.5781
# Iteration: 4106; Percent complete: 58.7%; Average loss: 2.4567
# Iteration: 4107; Percent complete: 58.7%; Average loss: 2.4184
# Iteration: 4108; Percent complete: 58.7%; Average loss: 2.4878
# Iteration: 4109; Percent complete: 58.7%; Average loss: 2.5154
# Iteration: 4110; Percent complete: 58.7%; Average loss: 2.4028
# Iteration: 4111; Percent complete: 58.7%; Average loss: 2.3409
# Iteration: 4112; Percent complete: 58.7%; Average loss: 2.4221
# Iteration: 4113; Percent complete: 58.8%; Average loss: 2.3462
# Iteration: 4114; Percent complete: 58.8%; Average loss: 2.6029
# Iteration: 4115; Percent complete: 58.8%; Average loss: 2.4856
# Iteration: 4116; Percent complete: 58.8%; Average loss: 2.6411
# Iteration: 4117; Percent complete: 58.8%; Average loss: 2.4228
# Iteration: 4118; Percent complete: 58.8%; Average loss: 2.4974
# Iteration: 4119; Percent complete: 58.8%; Average loss: 2.2634
# Iteration: 4120; Percent complete: 58.9%; Average loss: 2.5722
# Iteration: 4121; Percent complete: 58.9%; Average loss: 2.3277
# Iteration: 4122; Percent complete: 58.9%; Average loss: 2.3920
# Iteration: 4123; Percent complete: 58.9%; Average loss: 2.5545
# Iteration: 4124; Percent complete: 58.9%; Average loss: 2.6295
# Iteration: 4125; Percent complete: 58.9%; Average loss: 2.4244
# Iteration: 4126; Percent complete: 58.9%; Average loss: 2.4773
# Iteration: 4127; Percent complete: 59.0%; Average loss: 2.5537
# Iteration: 4128; Percent complete: 59.0%; Average loss: 2.6803
# Iteration: 4129; Percent complete: 59.0%; Average loss: 2.3588
# Iteration: 4130; Percent complete: 59.0%; Average loss: 2.3592
# Iteration: 4131; Percent complete: 59.0%; Average loss: 2.5927
# Iteration: 4132; Percent complete: 59.0%; Average loss: 2.2730
# Iteration: 4133; Percent complete: 59.0%; Average loss: 2.4300
# Iteration: 4134; Percent complete: 59.1%; Average loss: 2.6261
# Iteration: 4135; Percent complete: 59.1%; Average loss: 2.5016
# Iteration: 4136; Percent complete: 59.1%; Average loss: 2.6654
# Iteration: 4137; Percent complete: 59.1%; Average loss: 2.4559
# Iteration: 4138; Percent complete: 59.1%; Average loss: 2.5363
# Iteration: 4139; Percent complete: 59.1%; Average loss: 2.4899
# Iteration: 4140; Percent complete: 59.1%; Average loss: 2.4110
# Iteration: 4141; Percent complete: 59.2%; Average loss: 2.4700
# Iteration: 4142; Percent complete: 59.2%; Average loss: 2.4799
# Iteration: 4143; Percent complete: 59.2%; Average loss: 2.6596
# Iteration: 4144; Percent complete: 59.2%; Average loss: 2.4804
# Iteration: 4145; Percent complete: 59.2%; Average loss: 2.6864
# Iteration: 4146; Percent complete: 59.2%; Average loss: 2.2999
# Iteration: 4147; Percent complete: 59.2%; Average loss: 2.3146
# Iteration: 4148; Percent complete: 59.3%; Average loss: 2.5195
# Iteration: 4149; Percent complete: 59.3%; Average loss: 2.5332
# Iteration: 4150; Percent complete: 59.3%; Average loss: 2.5376
# Iteration: 4151; Percent complete: 59.3%; Average loss: 2.4817
# Iteration: 4152; Percent complete: 59.3%; Average loss: 2.4704
# Iteration: 4153; Percent complete: 59.3%; Average loss: 2.5987
# Iteration: 4154; Percent complete: 59.3%; Average loss: 2.4795
# Iteration: 4155; Percent complete: 59.4%; Average loss: 2.4953
# Iteration: 4156; Percent complete: 59.4%; Average loss: 2.5998
# Iteration: 4157; Percent complete: 59.4%; Average loss: 2.4296
# Iteration: 4158; Percent complete: 59.4%; Average loss: 2.7210
# Iteration: 4159; Percent complete: 59.4%; Average loss: 2.4207
# Iteration: 4160; Percent complete: 59.4%; Average loss: 2.4182
# Iteration: 4161; Percent complete: 59.4%; Average loss: 2.4160
# Iteration: 4162; Percent complete: 59.5%; Average loss: 2.6583
# Iteration: 4163; Percent complete: 59.5%; Average loss: 2.6806
# Iteration: 4164; Percent complete: 59.5%; Average loss: 2.5751
# Iteration: 4165; Percent complete: 59.5%; Average loss: 2.4506
# Iteration: 4166; Percent complete: 59.5%; Average loss: 2.5654
# Iteration: 4167; Percent complete: 59.5%; Average loss: 2.2717
# Iteration: 4168; Percent complete: 59.5%; Average loss: 2.5879
# Iteration: 4169; Percent complete: 59.6%; Average loss: 2.6192
# Iteration: 4170; Percent complete: 59.6%; Average loss: 2.6519
# Iteration: 4171; Percent complete: 59.6%; Average loss: 2.4993
# Iteration: 4172; Percent complete: 59.6%; Average loss: 2.4828
# Iteration: 4173; Percent complete: 59.6%; Average loss: 2.3346
# Iteration: 4174; Percent complete: 59.6%; Average loss: 2.4650
# Iteration: 4175; Percent complete: 59.6%; Average loss: 2.5507
# Iteration: 4176; Percent complete: 59.7%; Average loss: 2.2026
# Iteration: 4177; Percent complete: 59.7%; Average loss: 2.4617
# Iteration: 4178; Percent complete: 59.7%; Average loss: 2.7738
# Iteration: 4179; Percent complete: 59.7%; Average loss: 2.4949
# Iteration: 4180; Percent complete: 59.7%; Average loss: 2.3971
# Iteration: 4181; Percent complete: 59.7%; Average loss: 2.5530
# Iteration: 4182; Percent complete: 59.7%; Average loss: 2.4793
# Iteration: 4183; Percent complete: 59.8%; Average loss: 2.6472
# Iteration: 4184; Percent complete: 59.8%; Average loss: 2.3899
# Iteration: 4185; Percent complete: 59.8%; Average loss: 2.6291
# Iteration: 4186; Percent complete: 59.8%; Average loss: 2.4338
# Iteration: 4187; Percent complete: 59.8%; Average loss: 2.5887
# Iteration: 4188; Percent complete: 59.8%; Average loss: 2.3223
# Iteration: 4189; Percent complete: 59.8%; Average loss: 2.4828
# Iteration: 4190; Percent complete: 59.9%; Average loss: 2.3807
# Iteration: 4191; Percent complete: 59.9%; Average loss: 2.5477
# Iteration: 4192; Percent complete: 59.9%; Average loss: 2.5156
# Iteration: 4193; Percent complete: 59.9%; Average loss: 2.7066
# Iteration: 4194; Percent complete: 59.9%; Average loss: 2.3742
# Iteration: 4195; Percent complete: 59.9%; Average loss: 2.5189
# Iteration: 4196; Percent complete: 59.9%; Average loss: 2.4338
# Iteration: 4197; Percent complete: 60.0%; Average loss: 2.5041
# Iteration: 4198; Percent complete: 60.0%; Average loss: 2.3816
# Iteration: 4199; Percent complete: 60.0%; Average loss: 2.6026
# Iteration: 4200; Percent complete: 60.0%; Average loss: 2.4304
# Iteration: 4201; Percent complete: 60.0%; Average loss: 2.3574
# Iteration: 4202; Percent complete: 60.0%; Average loss: 2.4343
# Iteration: 4203; Percent complete: 60.0%; Average loss: 2.3532
# Iteration: 4204; Percent complete: 60.1%; Average loss: 2.4954
# Iteration: 4205; Percent complete: 60.1%; Average loss: 2.4293
# Iteration: 4206; Percent complete: 60.1%; Average loss: 2.6032
# Iteration: 4207; Percent complete: 60.1%; Average loss: 2.5038
# Iteration: 4208; Percent complete: 60.1%; Average loss: 2.6228
# Iteration: 4209; Percent complete: 60.1%; Average loss: 2.4367
# Iteration: 4210; Percent complete: 60.1%; Average loss: 2.3750
# Iteration: 4211; Percent complete: 60.2%; Average loss: 2.5139
# Iteration: 4212; Percent complete: 60.2%; Average loss: 2.4697
# Iteration: 4213; Percent complete: 60.2%; Average loss: 2.4613
# Iteration: 4214; Percent complete: 60.2%; Average loss: 2.6763
# Iteration: 4215; Percent complete: 60.2%; Average loss: 2.2075
# Iteration: 4216; Percent complete: 60.2%; Average loss: 2.4442
# Iteration: 4217; Percent complete: 60.2%; Average loss: 2.4873
# Iteration: 4218; Percent complete: 60.3%; Average loss: 2.4001
# Iteration: 4219; Percent complete: 60.3%; Average loss: 2.3936
# Iteration: 4220; Percent complete: 60.3%; Average loss: 2.3741
# Iteration: 4221; Percent complete: 60.3%; Average loss: 2.5792
# Iteration: 4222; Percent complete: 60.3%; Average loss: 2.3820
# Iteration: 4223; Percent complete: 60.3%; Average loss: 2.3860
# Iteration: 4224; Percent complete: 60.3%; Average loss: 2.5559
# Iteration: 4225; Percent complete: 60.4%; Average loss: 2.3833
# Iteration: 4226; Percent complete: 60.4%; Average loss: 2.3419
# Iteration: 4227; Percent complete: 60.4%; Average loss: 2.1827
# Iteration: 4228; Percent complete: 60.4%; Average loss: 2.3662
# Iteration: 4229; Percent complete: 60.4%; Average loss: 2.4686
# Iteration: 4230; Percent complete: 60.4%; Average loss: 2.5061
# Iteration: 4231; Percent complete: 60.4%; Average loss: 2.5429
# Iteration: 4232; Percent complete: 60.5%; Average loss: 2.4003
# Iteration: 4233; Percent complete: 60.5%; Average loss: 2.4162
# Iteration: 4234; Percent complete: 60.5%; Average loss: 2.4345
# Iteration: 4235; Percent complete: 60.5%; Average loss: 2.6429
# Iteration: 4236; Percent complete: 60.5%; Average loss: 2.2815
# Iteration: 4237; Percent complete: 60.5%; Average loss: 2.3081
# Iteration: 4238; Percent complete: 60.5%; Average loss: 2.3589
# Iteration: 4239; Percent complete: 60.6%; Average loss: 2.5291
# Iteration: 4240; Percent complete: 60.6%; Average loss: 2.4294
# Iteration: 4241; Percent complete: 60.6%; Average loss: 2.4215
# Iteration: 4242; Percent complete: 60.6%; Average loss: 2.6128
# Iteration: 4243; Percent complete: 60.6%; Average loss: 2.6325
# Iteration: 4244; Percent complete: 60.6%; Average loss: 2.6505
# Iteration: 4245; Percent complete: 60.6%; Average loss: 2.3187
# Iteration: 4246; Percent complete: 60.7%; Average loss: 2.3822
# Iteration: 4247; Percent complete: 60.7%; Average loss: 2.3019
# Iteration: 4248; Percent complete: 60.7%; Average loss: 2.4444
# Iteration: 4249; Percent complete: 60.7%; Average loss: 2.3542
# Iteration: 4250; Percent complete: 60.7%; Average loss: 2.2375
# Iteration: 4251; Percent complete: 60.7%; Average loss: 2.2057
# Iteration: 4252; Percent complete: 60.7%; Average loss: 2.3335
# Iteration: 4253; Percent complete: 60.8%; Average loss: 2.5303
# Iteration: 4254; Percent complete: 60.8%; Average loss: 2.5456
# Iteration: 4255; Percent complete: 60.8%; Average loss: 2.4031
# Iteration: 4256; Percent complete: 60.8%; Average loss: 2.4553
# Iteration: 4257; Percent complete: 60.8%; Average loss: 2.5444
# Iteration: 4258; Percent complete: 60.8%; Average loss: 2.4897
# Iteration: 4259; Percent complete: 60.8%; Average loss: 2.3571
# Iteration: 4260; Percent complete: 60.9%; Average loss: 2.4282
# Iteration: 4261; Percent complete: 60.9%; Average loss: 2.2487
# Iteration: 4262; Percent complete: 60.9%; Average loss: 2.4411
# Iteration: 4263; Percent complete: 60.9%; Average loss: 2.4073
# Iteration: 4264; Percent complete: 60.9%; Average loss: 2.3305
# Iteration: 4265; Percent complete: 60.9%; Average loss: 2.4410
# Iteration: 4266; Percent complete: 60.9%; Average loss: 2.4985
# Iteration: 4267; Percent complete: 61.0%; Average loss: 2.4896
# Iteration: 4268; Percent complete: 61.0%; Average loss: 2.2309
# Iteration: 4269; Percent complete: 61.0%; Average loss: 2.4184
# Iteration: 4270; Percent complete: 61.0%; Average loss: 2.3008
# Iteration: 4271; Percent complete: 61.0%; Average loss: 2.4801
# Iteration: 4272; Percent complete: 61.0%; Average loss: 2.5546
# Iteration: 4273; Percent complete: 61.0%; Average loss: 2.3489
# Iteration: 4274; Percent complete: 61.1%; Average loss: 2.5999
# Iteration: 4275; Percent complete: 61.1%; Average loss: 2.5723
# Iteration: 4276; Percent complete: 61.1%; Average loss: 2.6193
# Iteration: 4277; Percent complete: 61.1%; Average loss: 2.3777
# Iteration: 4278; Percent complete: 61.1%; Average loss: 2.4410
# Iteration: 4279; Percent complete: 61.1%; Average loss: 2.4669
# Iteration: 4280; Percent complete: 61.1%; Average loss: 2.4075
# Iteration: 4281; Percent complete: 61.2%; Average loss: 2.2352
# Iteration: 4282; Percent complete: 61.2%; Average loss: 2.3608
# Iteration: 4283; Percent complete: 61.2%; Average loss: 2.4126
# Iteration: 4284; Percent complete: 61.2%; Average loss: 2.3346
# Iteration: 4285; Percent complete: 61.2%; Average loss: 2.2773
# Iteration: 4286; Percent complete: 61.2%; Average loss: 2.6311
# Iteration: 4287; Percent complete: 61.2%; Average loss: 2.3441
# Iteration: 4288; Percent complete: 61.3%; Average loss: 2.5330
# Iteration: 4289; Percent complete: 61.3%; Average loss: 2.3162
# Iteration: 4290; Percent complete: 61.3%; Average loss: 2.5154
# Iteration: 4291; Percent complete: 61.3%; Average loss: 2.5720
# Iteration: 4292; Percent complete: 61.3%; Average loss: 2.3360
# Iteration: 4293; Percent complete: 61.3%; Average loss: 2.5259
# Iteration: 4294; Percent complete: 61.3%; Average loss: 2.4489
# Iteration: 4295; Percent complete: 61.4%; Average loss: 2.4102
# Iteration: 4296; Percent complete: 61.4%; Average loss: 2.5618
# Iteration: 4297; Percent complete: 61.4%; Average loss: 2.3964
# Iteration: 4298; Percent complete: 61.4%; Average loss: 2.3741
# Iteration: 4299; Percent complete: 61.4%; Average loss: 2.3711
# Iteration: 4300; Percent complete: 61.4%; Average loss: 2.5800
# Iteration: 4301; Percent complete: 61.4%; Average loss: 2.4542
# Iteration: 4302; Percent complete: 61.5%; Average loss: 2.3519
# Iteration: 4303; Percent complete: 61.5%; Average loss: 2.2347
# Iteration: 4304; Percent complete: 61.5%; Average loss: 2.3873
# Iteration: 4305; Percent complete: 61.5%; Average loss: 2.3236
# Iteration: 4306; Percent complete: 61.5%; Average loss: 2.2688
# Iteration: 4307; Percent complete: 61.5%; Average loss: 2.4900
# Iteration: 4308; Percent complete: 61.5%; Average loss: 2.4246
# Iteration: 4309; Percent complete: 61.6%; Average loss: 2.4242
# Iteration: 4310; Percent complete: 61.6%; Average loss: 2.3675
# Iteration: 4311; Percent complete: 61.6%; Average loss: 2.3943
# Iteration: 4312; Percent complete: 61.6%; Average loss: 2.4017
# Iteration: 4313; Percent complete: 61.6%; Average loss: 2.4906
# Iteration: 4314; Percent complete: 61.6%; Average loss: 2.4478
# Iteration: 4315; Percent complete: 61.6%; Average loss: 2.4457
# Iteration: 4316; Percent complete: 61.7%; Average loss: 2.4064
# Iteration: 4317; Percent complete: 61.7%; Average loss: 2.4341
# Iteration: 4318; Percent complete: 61.7%; Average loss: 2.3912
# Iteration: 4319; Percent complete: 61.7%; Average loss: 2.3686
# Iteration: 4320; Percent complete: 61.7%; Average loss: 2.4409
# Iteration: 4321; Percent complete: 61.7%; Average loss: 2.3347
# Iteration: 4322; Percent complete: 61.7%; Average loss: 2.3974
# Iteration: 4323; Percent complete: 61.8%; Average loss: 2.4447
# Iteration: 4324; Percent complete: 61.8%; Average loss: 2.4960
# Iteration: 4325; Percent complete: 61.8%; Average loss: 2.3178
# Iteration: 4326; Percent complete: 61.8%; Average loss: 2.3752
# Iteration: 4327; Percent complete: 61.8%; Average loss: 2.2759
# Iteration: 4328; Percent complete: 61.8%; Average loss: 2.5462
# Iteration: 4329; Percent complete: 61.8%; Average loss: 2.3679
# Iteration: 4330; Percent complete: 61.9%; Average loss: 2.3534
# Iteration: 4331; Percent complete: 61.9%; Average loss: 2.3356
# Iteration: 4332; Percent complete: 61.9%; Average loss: 2.3266
# Iteration: 4333; Percent complete: 61.9%; Average loss: 2.4082
# Iteration: 4334; Percent complete: 61.9%; Average loss: 2.3696
# Iteration: 4335; Percent complete: 61.9%; Average loss: 2.5218
# Iteration: 4336; Percent complete: 61.9%; Average loss: 2.4635
# Iteration: 4337; Percent complete: 62.0%; Average loss: 2.4074
# Iteration: 4338; Percent complete: 62.0%; Average loss: 2.5091
# Iteration: 4339; Percent complete: 62.0%; Average loss: 2.1731
# Iteration: 4340; Percent complete: 62.0%; Average loss: 2.4265
# Iteration: 4341; Percent complete: 62.0%; Average loss: 2.4985
# Iteration: 4342; Percent complete: 62.0%; Average loss: 2.4833
# Iteration: 4343; Percent complete: 62.0%; Average loss: 2.4202
# Iteration: 4344; Percent complete: 62.1%; Average loss: 2.4303
# Iteration: 4345; Percent complete: 62.1%; Average loss: 2.2108
# Iteration: 4346; Percent complete: 62.1%; Average loss: 2.3969
# Iteration: 4347; Percent complete: 62.1%; Average loss: 2.2816
# Iteration: 4348; Percent complete: 62.1%; Average loss: 2.3501
# Iteration: 4349; Percent complete: 62.1%; Average loss: 2.4630
# Iteration: 4350; Percent complete: 62.1%; Average loss: 2.5863
# Iteration: 4351; Percent complete: 62.2%; Average loss: 2.3712
# Iteration: 4352; Percent complete: 62.2%; Average loss: 2.3765
# Iteration: 4353; Percent complete: 62.2%; Average loss: 2.2779
# Iteration: 4354; Percent complete: 62.2%; Average loss: 2.6144
# Iteration: 4355; Percent complete: 62.2%; Average loss: 2.2263
# Iteration: 4356; Percent complete: 62.2%; Average loss: 2.7772
# Iteration: 4357; Percent complete: 62.2%; Average loss: 2.4587
# Iteration: 4358; Percent complete: 62.3%; Average loss: 2.3759
# Iteration: 4359; Percent complete: 62.3%; Average loss: 2.3029
# Iteration: 4360; Percent complete: 62.3%; Average loss: 2.4488
# Iteration: 4361; Percent complete: 62.3%; Average loss: 2.5148
# Iteration: 4362; Percent complete: 62.3%; Average loss: 2.3663
# Iteration: 4363; Percent complete: 62.3%; Average loss: 2.4315
# Iteration: 4364; Percent complete: 62.3%; Average loss: 2.4954
# Iteration: 4365; Percent complete: 62.4%; Average loss: 2.4194
# Iteration: 4366; Percent complete: 62.4%; Average loss: 2.4891
# Iteration: 4367; Percent complete: 62.4%; Average loss: 2.2186
# Iteration: 4368; Percent complete: 62.4%; Average loss: 2.3772
# Iteration: 4369; Percent complete: 62.4%; Average loss: 2.3858
# Iteration: 4370; Percent complete: 62.4%; Average loss: 2.3361
# Iteration: 4371; Percent complete: 62.4%; Average loss: 2.6035
# Iteration: 4372; Percent complete: 62.5%; Average loss: 2.3060
# Iteration: 4373; Percent complete: 62.5%; Average loss: 2.4350
# Iteration: 4374; Percent complete: 62.5%; Average loss: 2.5458
# Iteration: 4375; Percent complete: 62.5%; Average loss: 2.3517
# Iteration: 4376; Percent complete: 62.5%; Average loss: 2.4576
# Iteration: 4377; Percent complete: 62.5%; Average loss: 2.4053
# Iteration: 4378; Percent complete: 62.5%; Average loss: 2.2380
# Iteration: 4379; Percent complete: 62.6%; Average loss: 2.6294
# Iteration: 4380; Percent complete: 62.6%; Average loss: 2.5587
# Iteration: 4381; Percent complete: 62.6%; Average loss: 2.3092
# Iteration: 4382; Percent complete: 62.6%; Average loss: 2.4229
# Iteration: 4383; Percent complete: 62.6%; Average loss: 2.6196
# Iteration: 4384; Percent complete: 62.6%; Average loss: 2.2981
# Iteration: 4385; Percent complete: 62.6%; Average loss: 2.2303
# Iteration: 4386; Percent complete: 62.7%; Average loss: 2.5456
# Iteration: 4387; Percent complete: 62.7%; Average loss: 2.3369
# Iteration: 4388; Percent complete: 62.7%; Average loss: 2.5175
# Iteration: 4389; Percent complete: 62.7%; Average loss: 2.5690
# Iteration: 4390; Percent complete: 62.7%; Average loss: 2.3484
# Iteration: 4391; Percent complete: 62.7%; Average loss: 2.2961
# Iteration: 4392; Percent complete: 62.7%; Average loss: 2.6041
# Iteration: 4393; Percent complete: 62.8%; Average loss: 2.2406
# Iteration: 4394; Percent complete: 62.8%; Average loss: 2.2393
# Iteration: 4395; Percent complete: 62.8%; Average loss: 2.6076
# Iteration: 4396; Percent complete: 62.8%; Average loss: 2.5677
# Iteration: 4397; Percent complete: 62.8%; Average loss: 2.6117
# Iteration: 4398; Percent complete: 62.8%; Average loss: 2.1928
# Iteration: 4399; Percent complete: 62.8%; Average loss: 2.3492
# Iteration: 4400; Percent complete: 62.9%; Average loss: 2.1990
# Iteration: 4401; Percent complete: 62.9%; Average loss: 2.2490
# Iteration: 4402; Percent complete: 62.9%; Average loss: 2.4180
# Iteration: 4403; Percent complete: 62.9%; Average loss: 2.4945
# Iteration: 4404; Percent complete: 62.9%; Average loss: 2.4237
# Iteration: 4405; Percent complete: 62.9%; Average loss: 2.4406
# Iteration: 4406; Percent complete: 62.9%; Average loss: 2.5070
# Iteration: 4407; Percent complete: 63.0%; Average loss: 2.4044
# Iteration: 4408; Percent complete: 63.0%; Average loss: 2.2931
# Iteration: 4409; Percent complete: 63.0%; Average loss: 2.3600
# Iteration: 4410; Percent complete: 63.0%; Average loss: 2.3331
# Iteration: 4411; Percent complete: 63.0%; Average loss: 2.5631
# Iteration: 4412; Percent complete: 63.0%; Average loss: 2.5676
# Iteration: 4413; Percent complete: 63.0%; Average loss: 2.5668
# Iteration: 4414; Percent complete: 63.1%; Average loss: 2.2867
# Iteration: 4415; Percent complete: 63.1%; Average loss: 2.3720
# Iteration: 4416; Percent complete: 63.1%; Average loss: 2.2516
# Iteration: 4417; Percent complete: 63.1%; Average loss: 2.3301
# Iteration: 4418; Percent complete: 63.1%; Average loss: 2.4662
# Iteration: 4419; Percent complete: 63.1%; Average loss: 2.1608
# Iteration: 4420; Percent complete: 63.1%; Average loss: 2.3659
# Iteration: 4421; Percent complete: 63.2%; Average loss: 2.2868
# Iteration: 4422; Percent complete: 63.2%; Average loss: 2.4680
# Iteration: 4423; Percent complete: 63.2%; Average loss: 2.4080
# Iteration: 4424; Percent complete: 63.2%; Average loss: 2.2973
# Iteration: 4425; Percent complete: 63.2%; Average loss: 2.3173
# Iteration: 4426; Percent complete: 63.2%; Average loss: 2.3572
# Iteration: 4427; Percent complete: 63.2%; Average loss: 2.2890
# Iteration: 4428; Percent complete: 63.3%; Average loss: 2.4852
# Iteration: 4429; Percent complete: 63.3%; Average loss: 2.3213
# Iteration: 4430; Percent complete: 63.3%; Average loss: 2.4591
# Iteration: 4431; Percent complete: 63.3%; Average loss: 2.4195
# Iteration: 4432; Percent complete: 63.3%; Average loss: 2.3875
# Iteration: 4433; Percent complete: 63.3%; Average loss: 2.4739
# Iteration: 4434; Percent complete: 63.3%; Average loss: 2.3951
# Iteration: 4435; Percent complete: 63.4%; Average loss: 2.4793
# Iteration: 4436; Percent complete: 63.4%; Average loss: 2.4180
# Iteration: 4437; Percent complete: 63.4%; Average loss: 2.1264
# Iteration: 4438; Percent complete: 63.4%; Average loss: 2.5812
# Iteration: 4439; Percent complete: 63.4%; Average loss: 2.5264
# Iteration: 4440; Percent complete: 63.4%; Average loss: 2.4377
# Iteration: 4441; Percent complete: 63.4%; Average loss: 2.2450
# Iteration: 4442; Percent complete: 63.5%; Average loss: 2.7118
# Iteration: 4443; Percent complete: 63.5%; Average loss: 2.4772
# Iteration: 4444; Percent complete: 63.5%; Average loss: 2.5066
# Iteration: 4445; Percent complete: 63.5%; Average loss: 2.3974
# Iteration: 4446; Percent complete: 63.5%; Average loss: 2.6640
# Iteration: 4447; Percent complete: 63.5%; Average loss: 2.5023
# Iteration: 4448; Percent complete: 63.5%; Average loss: 2.3835
# Iteration: 4449; Percent complete: 63.6%; Average loss: 2.5566
# Iteration: 4450; Percent complete: 63.6%; Average loss: 2.2790
# Iteration: 4451; Percent complete: 63.6%; Average loss: 2.7225
# Iteration: 4452; Percent complete: 63.6%; Average loss: 2.4652
# Iteration: 4453; Percent complete: 63.6%; Average loss: 2.5683
# Iteration: 4454; Percent complete: 63.6%; Average loss: 2.5383
# Iteration: 4455; Percent complete: 63.6%; Average loss: 2.3673
# Iteration: 4456; Percent complete: 63.7%; Average loss: 2.4643
# Iteration: 4457; Percent complete: 63.7%; Average loss: 2.4508
# Iteration: 4458; Percent complete: 63.7%; Average loss: 2.3026
# Iteration: 4459; Percent complete: 63.7%; Average loss: 2.3926
# Iteration: 4460; Percent complete: 63.7%; Average loss: 2.3720
# Iteration: 4461; Percent complete: 63.7%; Average loss: 2.2700
# Iteration: 4462; Percent complete: 63.7%; Average loss: 2.5514
# Iteration: 4463; Percent complete: 63.8%; Average loss: 2.3332
# Iteration: 4464; Percent complete: 63.8%; Average loss: 2.3170
# Iteration: 4465; Percent complete: 63.8%; Average loss: 2.3641
# Iteration: 4466; Percent complete: 63.8%; Average loss: 2.3975
# Iteration: 4467; Percent complete: 63.8%; Average loss: 2.4163
# Iteration: 4468; Percent complete: 63.8%; Average loss: 2.3167
# Iteration: 4469; Percent complete: 63.8%; Average loss: 2.5006
# Iteration: 4470; Percent complete: 63.9%; Average loss: 2.4830
# Iteration: 4471; Percent complete: 63.9%; Average loss: 2.3100
# Iteration: 4472; Percent complete: 63.9%; Average loss: 2.4889
# Iteration: 4473; Percent complete: 63.9%; Average loss: 2.3780
# Iteration: 4474; Percent complete: 63.9%; Average loss: 2.5269
# Iteration: 4475; Percent complete: 63.9%; Average loss: 2.4291
# Iteration: 4476; Percent complete: 63.9%; Average loss: 2.4795
# Iteration: 4477; Percent complete: 64.0%; Average loss: 2.4360
# Iteration: 4478; Percent complete: 64.0%; Average loss: 2.4873
# Iteration: 4479; Percent complete: 64.0%; Average loss: 2.4480
# Iteration: 4480; Percent complete: 64.0%; Average loss: 2.4226
# Iteration: 4481; Percent complete: 64.0%; Average loss: 2.3803
# Iteration: 4482; Percent complete: 64.0%; Average loss: 2.5747
# Iteration: 4483; Percent complete: 64.0%; Average loss: 2.3805
# Iteration: 4484; Percent complete: 64.1%; Average loss: 2.2481
# Iteration: 4485; Percent complete: 64.1%; Average loss: 2.3341
# Iteration: 4486; Percent complete: 64.1%; Average loss: 2.2431
# Iteration: 4487; Percent complete: 64.1%; Average loss: 2.1820
# Iteration: 4488; Percent complete: 64.1%; Average loss: 2.3134
# Iteration: 4489; Percent complete: 64.1%; Average loss: 2.2446
# Iteration: 4490; Percent complete: 64.1%; Average loss: 2.4478
# Iteration: 4491; Percent complete: 64.2%; Average loss: 2.4309
# Iteration: 4492; Percent complete: 64.2%; Average loss: 2.4383
# Iteration: 4493; Percent complete: 64.2%; Average loss: 2.5082
# Iteration: 4494; Percent complete: 64.2%; Average loss: 2.3874
# Iteration: 4495; Percent complete: 64.2%; Average loss: 2.6109
# Iteration: 4496; Percent complete: 64.2%; Average loss: 2.3336
# Iteration: 4497; Percent complete: 64.2%; Average loss: 2.3992
# Iteration: 4498; Percent complete: 64.3%; Average loss: 2.4340
# Iteration: 4499; Percent complete: 64.3%; Average loss: 2.5120
# Iteration: 4500; Percent complete: 64.3%; Average loss: 2.3813
# Iteration: 4501; Percent complete: 64.3%; Average loss: 2.3457
# Iteration: 4502; Percent complete: 64.3%; Average loss: 2.2799
# Iteration: 4503; Percent complete: 64.3%; Average loss: 2.3259
# Iteration: 4504; Percent complete: 64.3%; Average loss: 2.2892
# Iteration: 4505; Percent complete: 64.4%; Average loss: 2.3043
# Iteration: 4506; Percent complete: 64.4%; Average loss: 2.4740
# Iteration: 4507; Percent complete: 64.4%; Average loss: 2.2854
# Iteration: 4508; Percent complete: 64.4%; Average loss: 2.3465
# Iteration: 4509; Percent complete: 64.4%; Average loss: 2.3553
# Iteration: 4510; Percent complete: 64.4%; Average loss: 2.4359
# Iteration: 4511; Percent complete: 64.4%; Average loss: 2.3913
# Iteration: 4512; Percent complete: 64.5%; Average loss: 2.4825
# Iteration: 4513; Percent complete: 64.5%; Average loss: 2.1240
# Iteration: 4514; Percent complete: 64.5%; Average loss: 2.3476
# Iteration: 4515; Percent complete: 64.5%; Average loss: 2.4797
# Iteration: 4516; Percent complete: 64.5%; Average loss: 2.2643
# Iteration: 4517; Percent complete: 64.5%; Average loss: 2.4264
# Iteration: 4518; Percent complete: 64.5%; Average loss: 2.2978
# Iteration: 4519; Percent complete: 64.6%; Average loss: 2.5954
# Iteration: 4520; Percent complete: 64.6%; Average loss: 2.3747
# Iteration: 4521; Percent complete: 64.6%; Average loss: 2.3828
# Iteration: 4522; Percent complete: 64.6%; Average loss: 2.2958
# Iteration: 4523; Percent complete: 64.6%; Average loss: 2.0758
# Iteration: 4524; Percent complete: 64.6%; Average loss: 2.4159
# Iteration: 4525; Percent complete: 64.6%; Average loss: 2.2590
# Iteration: 4526; Percent complete: 64.7%; Average loss: 2.4365
# Iteration: 4527; Percent complete: 64.7%; Average loss: 2.3526
# Iteration: 4528; Percent complete: 64.7%; Average loss: 2.3595
# Iteration: 4529; Percent complete: 64.7%; Average loss: 2.5044
# Iteration: 4530; Percent complete: 64.7%; Average loss: 2.5049
# Iteration: 4531; Percent complete: 64.7%; Average loss: 2.4663
# Iteration: 4532; Percent complete: 64.7%; Average loss: 2.5113
# Iteration: 4533; Percent complete: 64.8%; Average loss: 2.5095
# Iteration: 4534; Percent complete: 64.8%; Average loss: 2.4289
# Iteration: 4535; Percent complete: 64.8%; Average loss: 2.4161
# Iteration: 4536; Percent complete: 64.8%; Average loss: 2.3436
# Iteration: 4537; Percent complete: 64.8%; Average loss: 2.2240
# Iteration: 4538; Percent complete: 64.8%; Average loss: 2.4261
# Iteration: 4539; Percent complete: 64.8%; Average loss: 2.2052
# Iteration: 4540; Percent complete: 64.9%; Average loss: 2.3924
# Iteration: 4541; Percent complete: 64.9%; Average loss: 2.4949
# Iteration: 4542; Percent complete: 64.9%; Average loss: 2.3527
# Iteration: 4543; Percent complete: 64.9%; Average loss: 2.4248
# Iteration: 4544; Percent complete: 64.9%; Average loss: 2.4661
# Iteration: 4545; Percent complete: 64.9%; Average loss: 2.4146
# Iteration: 4546; Percent complete: 64.9%; Average loss: 2.3371
# Iteration: 4547; Percent complete: 65.0%; Average loss: 2.1523
# Iteration: 4548; Percent complete: 65.0%; Average loss: 2.4047
# Iteration: 4549; Percent complete: 65.0%; Average loss: 2.2316
# Iteration: 4550; Percent complete: 65.0%; Average loss: 2.4278
# Iteration: 4551; Percent complete: 65.0%; Average loss: 2.2885
# Iteration: 4552; Percent complete: 65.0%; Average loss: 2.4678
# Iteration: 4553; Percent complete: 65.0%; Average loss: 2.5816
# Iteration: 4554; Percent complete: 65.1%; Average loss: 2.3012
# Iteration: 4555; Percent complete: 65.1%; Average loss: 2.3458
# Iteration: 4556; Percent complete: 65.1%; Average loss: 2.4808
# Iteration: 4557; Percent complete: 65.1%; Average loss: 2.4523
# Iteration: 4558; Percent complete: 65.1%; Average loss: 2.1861
# Iteration: 4559; Percent complete: 65.1%; Average loss: 2.5156
# Iteration: 4560; Percent complete: 65.1%; Average loss: 2.3063
# Iteration: 4561; Percent complete: 65.2%; Average loss: 2.4557
# Iteration: 4562; Percent complete: 65.2%; Average loss: 2.2233
# Iteration: 4563; Percent complete: 65.2%; Average loss: 2.3957
# Iteration: 4564; Percent complete: 65.2%; Average loss: 2.3661
# Iteration: 4565; Percent complete: 65.2%; Average loss: 2.3630
# Iteration: 4566; Percent complete: 65.2%; Average loss: 2.5594
# Iteration: 4567; Percent complete: 65.2%; Average loss: 2.2225
# Iteration: 4568; Percent complete: 65.3%; Average loss: 2.3758
# Iteration: 4569; Percent complete: 65.3%; Average loss: 2.4734
# Iteration: 4570; Percent complete: 65.3%; Average loss: 2.4694
# Iteration: 4571; Percent complete: 65.3%; Average loss: 2.3382
# Iteration: 4572; Percent complete: 65.3%; Average loss: 2.2784
# Iteration: 4573; Percent complete: 65.3%; Average loss: 2.6236
# Iteration: 4574; Percent complete: 65.3%; Average loss: 2.3318
# Iteration: 4575; Percent complete: 65.4%; Average loss: 2.4097
# Iteration: 4576; Percent complete: 65.4%; Average loss: 2.5154
# Iteration: 4577; Percent complete: 65.4%; Average loss: 2.3484
# Iteration: 4578; Percent complete: 65.4%; Average loss: 2.3665
# Iteration: 4579; Percent complete: 65.4%; Average loss: 2.3274
# Iteration: 4580; Percent complete: 65.4%; Average loss: 2.4565
# Iteration: 4581; Percent complete: 65.4%; Average loss: 2.4923
# Iteration: 4582; Percent complete: 65.5%; Average loss: 2.3163
# Iteration: 4583; Percent complete: 65.5%; Average loss: 2.2939
# Iteration: 4584; Percent complete: 65.5%; Average loss: 2.1665
# Iteration: 4585; Percent complete: 65.5%; Average loss: 2.3639
# Iteration: 4586; Percent complete: 65.5%; Average loss: 2.2965
# Iteration: 4587; Percent complete: 65.5%; Average loss: 2.4483
# Iteration: 4588; Percent complete: 65.5%; Average loss: 2.4820
# Iteration: 4589; Percent complete: 65.6%; Average loss: 2.3002
# Iteration: 4590; Percent complete: 65.6%; Average loss: 2.5758
# Iteration: 4591; Percent complete: 65.6%; Average loss: 2.3168
# Iteration: 4592; Percent complete: 65.6%; Average loss: 2.4733
# Iteration: 4593; Percent complete: 65.6%; Average loss: 2.5497
# Iteration: 4594; Percent complete: 65.6%; Average loss: 2.3210
# Iteration: 4595; Percent complete: 65.6%; Average loss: 2.3159
# Iteration: 4596; Percent complete: 65.7%; Average loss: 2.3340
# Iteration: 4597; Percent complete: 65.7%; Average loss: 2.2742
# Iteration: 4598; Percent complete: 65.7%; Average loss: 2.3908
# Iteration: 4599; Percent complete: 65.7%; Average loss: 2.4701
# Iteration: 4600; Percent complete: 65.7%; Average loss: 2.2903
# Iteration: 4601; Percent complete: 65.7%; Average loss: 2.5168
# Iteration: 4602; Percent complete: 65.7%; Average loss: 2.3133
# Iteration: 4603; Percent complete: 65.8%; Average loss: 2.1962
# Iteration: 4604; Percent complete: 65.8%; Average loss: 2.3112
# Iteration: 4605; Percent complete: 65.8%; Average loss: 2.3262
# Iteration: 4606; Percent complete: 65.8%; Average loss: 2.3371
# Iteration: 4607; Percent complete: 65.8%; Average loss: 2.2428
# Iteration: 4608; Percent complete: 65.8%; Average loss: 2.4557
# Iteration: 4609; Percent complete: 65.8%; Average loss: 2.3877
# Iteration: 4610; Percent complete: 65.9%; Average loss: 2.2586
# Iteration: 4611; Percent complete: 65.9%; Average loss: 2.4154
# Iteration: 4612; Percent complete: 65.9%; Average loss: 2.4417
# Iteration: 4613; Percent complete: 65.9%; Average loss: 2.3191
# Iteration: 4614; Percent complete: 65.9%; Average loss: 2.4429
# Iteration: 4615; Percent complete: 65.9%; Average loss: 2.3560
# Iteration: 4616; Percent complete: 65.9%; Average loss: 2.4284
# Iteration: 4617; Percent complete: 66.0%; Average loss: 2.3380
# Iteration: 4618; Percent complete: 66.0%; Average loss: 2.4254
# Iteration: 4619; Percent complete: 66.0%; Average loss: 2.1661
# Iteration: 4620; Percent complete: 66.0%; Average loss: 2.2404
# Iteration: 4621; Percent complete: 66.0%; Average loss: 2.5090
# Iteration: 4622; Percent complete: 66.0%; Average loss: 2.1356
# Iteration: 4623; Percent complete: 66.0%; Average loss: 2.4868
# Iteration: 4624; Percent complete: 66.1%; Average loss: 2.2232
# Iteration: 4625; Percent complete: 66.1%; Average loss: 2.1602
# Iteration: 4626; Percent complete: 66.1%; Average loss: 2.4579
# Iteration: 4627; Percent complete: 66.1%; Average loss: 2.2477
# Iteration: 4628; Percent complete: 66.1%; Average loss: 2.3000
# Iteration: 4629; Percent complete: 66.1%; Average loss: 2.3435
# Iteration: 4630; Percent complete: 66.1%; Average loss: 2.4223
# Iteration: 4631; Percent complete: 66.2%; Average loss: 2.2362
# Iteration: 4632; Percent complete: 66.2%; Average loss: 2.1675
# Iteration: 4633; Percent complete: 66.2%; Average loss: 2.2664
# Iteration: 4634; Percent complete: 66.2%; Average loss: 2.3211
# Iteration: 4635; Percent complete: 66.2%; Average loss: 2.4213
# Iteration: 4636; Percent complete: 66.2%; Average loss: 2.4202
# Iteration: 4637; Percent complete: 66.2%; Average loss: 2.2808
# Iteration: 4638; Percent complete: 66.3%; Average loss: 2.4212
# Iteration: 4639; Percent complete: 66.3%; Average loss: 2.2416
# Iteration: 4640; Percent complete: 66.3%; Average loss: 2.5157
# Iteration: 4641; Percent complete: 66.3%; Average loss: 2.4214
# Iteration: 4642; Percent complete: 66.3%; Average loss: 2.3867
# Iteration: 4643; Percent complete: 66.3%; Average loss: 2.5244
# Iteration: 4644; Percent complete: 66.3%; Average loss: 2.3680
# Iteration: 4645; Percent complete: 66.4%; Average loss: 2.4881
# Iteration: 4646; Percent complete: 66.4%; Average loss: 2.4298
# Iteration: 4647; Percent complete: 66.4%; Average loss: 2.3774
# Iteration: 4648; Percent complete: 66.4%; Average loss: 2.3105
# Iteration: 4649; Percent complete: 66.4%; Average loss: 2.3185
# Iteration: 4650; Percent complete: 66.4%; Average loss: 2.4713
# Iteration: 4651; Percent complete: 66.4%; Average loss: 2.3368
# Iteration: 4652; Percent complete: 66.5%; Average loss: 2.1563
# Iteration: 4653; Percent complete: 66.5%; Average loss: 2.3301
# Iteration: 4654; Percent complete: 66.5%; Average loss: 2.4112
# Iteration: 4655; Percent complete: 66.5%; Average loss: 2.5032
# Iteration: 4656; Percent complete: 66.5%; Average loss: 2.3909
# Iteration: 4657; Percent complete: 66.5%; Average loss: 2.5564
# Iteration: 4658; Percent complete: 66.5%; Average loss: 2.5465
# Iteration: 4659; Percent complete: 66.6%; Average loss: 2.4933
# Iteration: 4660; Percent complete: 66.6%; Average loss: 2.2886
# Iteration: 4661; Percent complete: 66.6%; Average loss: 2.3904
# Iteration: 4662; Percent complete: 66.6%; Average loss: 2.4172
# Iteration: 4663; Percent complete: 66.6%; Average loss: 2.1771
# Iteration: 4664; Percent complete: 66.6%; Average loss: 2.5658
# Iteration: 4665; Percent complete: 66.6%; Average loss: 2.5703
# Iteration: 4666; Percent complete: 66.7%; Average loss: 2.2363
# Iteration: 4667; Percent complete: 66.7%; Average loss: 2.3945
# Iteration: 4668; Percent complete: 66.7%; Average loss: 2.3157
# Iteration: 4669; Percent complete: 66.7%; Average loss: 2.3841
# Iteration: 4670; Percent complete: 66.7%; Average loss: 2.2344
# Iteration: 4671; Percent complete: 66.7%; Average loss: 2.4467
# Iteration: 4672; Percent complete: 66.7%; Average loss: 2.2028
# Iteration: 4673; Percent complete: 66.8%; Average loss: 2.3539
# Iteration: 4674; Percent complete: 66.8%; Average loss: 2.3329
# Iteration: 4675; Percent complete: 66.8%; Average loss: 2.3994
# Iteration: 4676; Percent complete: 66.8%; Average loss: 2.3516
# Iteration: 4677; Percent complete: 66.8%; Average loss: 2.3554
# Iteration: 4678; Percent complete: 66.8%; Average loss: 2.3072
# Iteration: 4679; Percent complete: 66.8%; Average loss: 2.3905
# Iteration: 4680; Percent complete: 66.9%; Average loss: 2.2422
# Iteration: 4681; Percent complete: 66.9%; Average loss: 2.5783
# Iteration: 4682; Percent complete: 66.9%; Average loss: 2.4551
# Iteration: 4683; Percent complete: 66.9%; Average loss: 2.3788
# Iteration: 4684; Percent complete: 66.9%; Average loss: 2.5725
# Iteration: 4685; Percent complete: 66.9%; Average loss: 2.6548
# Iteration: 4686; Percent complete: 66.9%; Average loss: 2.4018
# Iteration: 4687; Percent complete: 67.0%; Average loss: 2.2344
# Iteration: 4688; Percent complete: 67.0%; Average loss: 2.3860
# Iteration: 4689; Percent complete: 67.0%; Average loss: 2.4404
# Iteration: 4690; Percent complete: 67.0%; Average loss: 2.2368
# Iteration: 4691; Percent complete: 67.0%; Average loss: 2.3894
# Iteration: 4692; Percent complete: 67.0%; Average loss: 2.5625
# Iteration: 4693; Percent complete: 67.0%; Average loss: 2.5044
# Iteration: 4694; Percent complete: 67.1%; Average loss: 2.4192
# Iteration: 4695; Percent complete: 67.1%; Average loss: 2.5036
# Iteration: 4696; Percent complete: 67.1%; Average loss: 2.3909
# Iteration: 4697; Percent complete: 67.1%; Average loss: 2.3235
# Iteration: 4698; Percent complete: 67.1%; Average loss: 2.3206
# Iteration: 4699; Percent complete: 67.1%; Average loss: 2.3813
# Iteration: 4700; Percent complete: 67.1%; Average loss: 2.4582
# Iteration: 4701; Percent complete: 67.2%; Average loss: 2.5629
# Iteration: 4702; Percent complete: 67.2%; Average loss: 2.1381
# Iteration: 4703; Percent complete: 67.2%; Average loss: 2.5988
# Iteration: 4704; Percent complete: 67.2%; Average loss: 2.1868
# Iteration: 4705; Percent complete: 67.2%; Average loss: 2.4488
# Iteration: 4706; Percent complete: 67.2%; Average loss: 2.4317
# Iteration: 4707; Percent complete: 67.2%; Average loss: 2.3000
# Iteration: 4708; Percent complete: 67.3%; Average loss: 2.2992
# Iteration: 4709; Percent complete: 67.3%; Average loss: 2.2907
# Iteration: 4710; Percent complete: 67.3%; Average loss: 2.3905
# Iteration: 4711; Percent complete: 67.3%; Average loss: 2.2585
# Iteration: 4712; Percent complete: 67.3%; Average loss: 2.5305
# Iteration: 4713; Percent complete: 67.3%; Average loss: 2.4207
# Iteration: 4714; Percent complete: 67.3%; Average loss: 2.7408
# Iteration: 4715; Percent complete: 67.4%; Average loss: 2.2641
# Iteration: 4716; Percent complete: 67.4%; Average loss: 2.3262
# Iteration: 4717; Percent complete: 67.4%; Average loss: 2.2184
# Iteration: 4718; Percent complete: 67.4%; Average loss: 2.2214
# Iteration: 4719; Percent complete: 67.4%; Average loss: 2.2867
# Iteration: 4720; Percent complete: 67.4%; Average loss: 2.6053
# Iteration: 4721; Percent complete: 67.4%; Average loss: 2.3278
# Iteration: 4722; Percent complete: 67.5%; Average loss: 2.3450
# Iteration: 4723; Percent complete: 67.5%; Average loss: 2.5700
# Iteration: 4724; Percent complete: 67.5%; Average loss: 2.2270
# Iteration: 4725; Percent complete: 67.5%; Average loss: 2.2186
# Iteration: 4726; Percent complete: 67.5%; Average loss: 2.2776
# Iteration: 4727; Percent complete: 67.5%; Average loss: 2.1640
# Iteration: 4728; Percent complete: 67.5%; Average loss: 2.3766
# Iteration: 4729; Percent complete: 67.6%; Average loss: 2.3631
# Iteration: 4730; Percent complete: 67.6%; Average loss: 2.2947
# Iteration: 4731; Percent complete: 67.6%; Average loss: 2.5951
# Iteration: 4732; Percent complete: 67.6%; Average loss: 2.1604
# Iteration: 4733; Percent complete: 67.6%; Average loss: 2.2958
# Iteration: 4734; Percent complete: 67.6%; Average loss: 2.1280
# Iteration: 4735; Percent complete: 67.6%; Average loss: 2.3597
# Iteration: 4736; Percent complete: 67.7%; Average loss: 2.5895
# Iteration: 4737; Percent complete: 67.7%; Average loss: 2.0996
# Iteration: 4738; Percent complete: 67.7%; Average loss: 2.3360
# Iteration: 4739; Percent complete: 67.7%; Average loss: 2.3239
# Iteration: 4740; Percent complete: 67.7%; Average loss: 2.6191
# Iteration: 4741; Percent complete: 67.7%; Average loss: 2.3426
# Iteration: 4742; Percent complete: 67.7%; Average loss: 2.3892
# Iteration: 4743; Percent complete: 67.8%; Average loss: 2.4463
# Iteration: 4744; Percent complete: 67.8%; Average loss: 2.2925
# Iteration: 4745; Percent complete: 67.8%; Average loss: 2.3434
# Iteration: 4746; Percent complete: 67.8%; Average loss: 2.4308
# Iteration: 4747; Percent complete: 67.8%; Average loss: 2.3570
# Iteration: 4748; Percent complete: 67.8%; Average loss: 2.4619
# Iteration: 4749; Percent complete: 67.8%; Average loss: 2.3218
# Iteration: 4750; Percent complete: 67.9%; Average loss: 2.4553
# Iteration: 4751; Percent complete: 67.9%; Average loss: 2.4205
# Iteration: 4752; Percent complete: 67.9%; Average loss: 2.4592
# Iteration: 4753; Percent complete: 67.9%; Average loss: 2.5242
# Iteration: 4754; Percent complete: 67.9%; Average loss: 2.2639
# Iteration: 4755; Percent complete: 67.9%; Average loss: 2.4985
# Iteration: 4756; Percent complete: 67.9%; Average loss: 2.4068
# Iteration: 4757; Percent complete: 68.0%; Average loss: 2.2982
# Iteration: 4758; Percent complete: 68.0%; Average loss: 2.2825
# Iteration: 4759; Percent complete: 68.0%; Average loss: 2.4104
# Iteration: 4760; Percent complete: 68.0%; Average loss: 2.4300
# ...
# Iteration: 6748; Percent complete: 96.4%; Average loss: 1.9832
# Iteration: 6749; Percent complete: 96.4%; Average loss: 1.8533
# Iteration: 6750; Percent complete: 96.4%; Average loss: 1.8463
# Iteration: 6751; Percent complete: 96.4%; Average loss: 1.9791
# Iteration: 6752; Percent complete: 96.5%; Average loss: 2.1388
# Iteration: 6753; Percent complete: 96.5%; Average loss: 1.9242
# Iteration: 6754; Percent complete: 96.5%; Average loss: 2.0898
# Iteration: 6755; Percent complete: 96.5%; Average loss: 2.1167
# Iteration: 6756; Percent complete: 96.5%; Average loss: 2.0306
# Iteration: 6757; Percent complete: 96.5%; Average loss: 2.1444
# Iteration: 6758; Percent complete: 96.5%; Average loss: 1.9169
# Iteration: 6759; Percent complete: 96.6%; Average loss: 2.0856
# Iteration: 6760; Percent complete: 96.6%; Average loss: 2.0238
# Iteration: 6761; Percent complete: 96.6%; Average loss: 1.9062
# Iteration: 6762; Percent complete: 96.6%; Average loss: 1.9968
# Iteration: 6763; Percent complete: 96.6%; Average loss: 2.0332
# Iteration: 6764; Percent complete: 96.6%; Average loss: 2.1882
# Iteration: 6765; Percent complete: 96.6%; Average loss: 2.0159
# Iteration: 6766; Percent complete: 96.7%; Average loss: 1.9300
# Iteration: 6767; Percent complete: 96.7%; Average loss: 2.0943
# Iteration: 6768; Percent complete: 96.7%; Average loss: 1.7656
# Iteration: 6769; Percent complete: 96.7%; Average loss: 1.8933
# Iteration: 6770; Percent complete: 96.7%; Average loss: 1.9821
# Iteration: 6771; Percent complete: 96.7%; Average loss: 2.0034
# Iteration: 6772; Percent complete: 96.7%; Average loss: 2.1586
# Iteration: 6773; Percent complete: 96.8%; Average loss: 2.1101
# Iteration: 6774; Percent complete: 96.8%; Average loss: 2.0686
# Iteration: 6775; Percent complete: 96.8%; Average loss: 2.1239
# Iteration: 6776; Percent complete: 96.8%; Average loss: 2.1263
# Iteration: 6777; Percent complete: 96.8%; Average loss: 2.2785
# Iteration: 6778; Percent complete: 96.8%; Average loss: 2.0890
# Iteration: 6779; Percent complete: 96.8%; Average loss: 2.1129
# Iteration: 6780; Percent complete: 96.9%; Average loss: 2.2730
# Iteration: 6781; Percent complete: 96.9%; Average loss: 1.9816
# Iteration: 6782; Percent complete: 96.9%; Average loss: 2.0355
# Iteration: 6783; Percent complete: 96.9%; Average loss: 1.9576
# Iteration: 6784; Percent complete: 96.9%; Average loss: 2.0070
# Iteration: 6785; Percent complete: 96.9%; Average loss: 1.9200
# Iteration: 6786; Percent complete: 96.9%; Average loss: 2.2632
# Iteration: 6787; Percent complete: 97.0%; Average loss: 2.0815
# Iteration: 6788; Percent complete: 97.0%; Average loss: 2.0014
# Iteration: 6789; Percent complete: 97.0%; Average loss: 2.1262
# Iteration: 6790; Percent complete: 97.0%; Average loss: 2.1962
# Iteration: 6791; Percent complete: 97.0%; Average loss: 2.1544
# Iteration: 6792; Percent complete: 97.0%; Average loss: 2.0220
# Iteration: 6793; Percent complete: 97.0%; Average loss: 2.0983
# Iteration: 6794; Percent complete: 97.1%; Average loss: 2.0698
# Iteration: 6795; Percent complete: 97.1%; Average loss: 1.9642
# Iteration: 6796; Percent complete: 97.1%; Average loss: 2.1584
# Iteration: 6797; Percent complete: 97.1%; Average loss: 2.0481
# Iteration: 6798; Percent complete: 97.1%; Average loss: 2.1466
# Iteration: 6799; Percent complete: 97.1%; Average loss: 2.1188
# Iteration: 6800; Percent complete: 97.1%; Average loss: 1.8969
# Iteration: 6801; Percent complete: 97.2%; Average loss: 2.0148
# Iteration: 6802; Percent complete: 97.2%; Average loss: 1.9231
# Iteration: 6803; Percent complete: 97.2%; Average loss: 2.0160
# Iteration: 6804; Percent complete: 97.2%; Average loss: 2.1143
# Iteration: 6805; Percent complete: 97.2%; Average loss: 2.0735
# Iteration: 6806; Percent complete: 97.2%; Average loss: 1.9392
# Iteration: 6807; Percent complete: 97.2%; Average loss: 1.8596
# Iteration: 6808; Percent complete: 97.3%; Average loss: 1.8567
# Iteration: 6809; Percent complete: 97.3%; Average loss: 2.0718
# Iteration: 6810; Percent complete: 97.3%; Average loss: 2.0477
# Iteration: 6811; Percent complete: 97.3%; Average loss: 2.0514
# Iteration: 6812; Percent complete: 97.3%; Average loss: 2.1941
# Iteration: 6813; Percent complete: 97.3%; Average loss: 2.1915
# Iteration: 6814; Percent complete: 97.3%; Average loss: 2.0580
# Iteration: 6815; Percent complete: 97.4%; Average loss: 2.1894
# Iteration: 6816; Percent complete: 97.4%; Average loss: 1.9936
# Iteration: 6817; Percent complete: 97.4%; Average loss: 2.1208
# Iteration: 6818; Percent complete: 97.4%; Average loss: 2.0259
# Iteration: 6819; Percent complete: 97.4%; Average loss: 2.1588
# Iteration: 6820; Percent complete: 97.4%; Average loss: 2.2310
# Iteration: 6821; Percent complete: 97.4%; Average loss: 1.8727
# Iteration: 6822; Percent complete: 97.5%; Average loss: 1.8248
# Iteration: 6823; Percent complete: 97.5%; Average loss: 2.1437
# Iteration: 6824; Percent complete: 97.5%; Average loss: 2.1230
# Iteration: 6825; Percent complete: 97.5%; Average loss: 1.9227
# Iteration: 6826; Percent complete: 97.5%; Average loss: 2.0295
# Iteration: 6827; Percent complete: 97.5%; Average loss: 2.0438
# Iteration: 6828; Percent complete: 97.5%; Average loss: 2.0105
# Iteration: 6829; Percent complete: 97.6%; Average loss: 1.9639
# Iteration: 6830; Percent complete: 97.6%; Average loss: 2.0349
# Iteration: 6831; Percent complete: 97.6%; Average loss: 2.1180
# Iteration: 6832; Percent complete: 97.6%; Average loss: 1.8638
# Iteration: 6833; Percent complete: 97.6%; Average loss: 2.0646
# Iteration: 6834; Percent complete: 97.6%; Average loss: 2.0813
# Iteration: 6835; Percent complete: 97.6%; Average loss: 2.0405
# Iteration: 6836; Percent complete: 97.7%; Average loss: 1.9878
# Iteration: 6837; Percent complete: 97.7%; Average loss: 2.0901
# Iteration: 6838; Percent complete: 97.7%; Average loss: 1.9309
# Iteration: 6839; Percent complete: 97.7%; Average loss: 2.0567
# Iteration: 6840; Percent complete: 97.7%; Average loss: 1.9470
# Iteration: 6841; Percent complete: 97.7%; Average loss: 1.9780
# Iteration: 6842; Percent complete: 97.7%; Average loss: 2.0563
# Iteration: 6843; Percent complete: 97.8%; Average loss: 2.0502
# Iteration: 6844; Percent complete: 97.8%; Average loss: 2.0071
# Iteration: 6845; Percent complete: 97.8%; Average loss: 1.8247
# Iteration: 6846; Percent complete: 97.8%; Average loss: 1.8780
# Iteration: 6847; Percent complete: 97.8%; Average loss: 2.0990
# Iteration: 6848; Percent complete: 97.8%; Average loss: 2.0690
# Iteration: 6849; Percent complete: 97.8%; Average loss: 2.1451
# Iteration: 6850; Percent complete: 97.9%; Average loss: 1.9618
# Iteration: 6851; Percent complete: 97.9%; Average loss: 1.9647
# Iteration: 6852; Percent complete: 97.9%; Average loss: 2.2474
# Iteration: 6853; Percent complete: 97.9%; Average loss: 1.9507
# Iteration: 6854; Percent complete: 97.9%; Average loss: 1.7937
# Iteration: 6855; Percent complete: 97.9%; Average loss: 1.8619
# Iteration: 6856; Percent complete: 97.9%; Average loss: 2.0041
# Iteration: 6857; Percent complete: 98.0%; Average loss: 1.9998
# Iteration: 6858; Percent complete: 98.0%; Average loss: 1.9910
# Iteration: 6859; Percent complete: 98.0%; Average loss: 2.0783
# Iteration: 6860; Percent complete: 98.0%; Average loss: 1.9363
# Iteration: 6861; Percent complete: 98.0%; Average loss: 2.0330
# Iteration: 6862; Percent complete: 98.0%; Average loss: 2.1634
# Iteration: 6863; Percent complete: 98.0%; Average loss: 2.0870
# Iteration: 6864; Percent complete: 98.1%; Average loss: 2.0850
# Iteration: 6865; Percent complete: 98.1%; Average loss: 2.1671
# Iteration: 6866; Percent complete: 98.1%; Average loss: 2.0193
# Iteration: 6867; Percent complete: 98.1%; Average loss: 1.8162
# Iteration: 6868; Percent complete: 98.1%; Average loss: 1.8152
# Iteration: 6869; Percent complete: 98.1%; Average loss: 1.8898
# Iteration: 6870; Percent complete: 98.1%; Average loss: 1.9266
# Iteration: 6871; Percent complete: 98.2%; Average loss: 2.0957
# Iteration: 6872; Percent complete: 98.2%; Average loss: 1.9519
# Iteration: 6873; Percent complete: 98.2%; Average loss: 2.0042
# Iteration: 6874; Percent complete: 98.2%; Average loss: 1.8313
# Iteration: 6875; Percent complete: 98.2%; Average loss: 2.0363
# Iteration: 6876; Percent complete: 98.2%; Average loss: 2.0422
# Iteration: 6877; Percent complete: 98.2%; Average loss: 1.7662
# Iteration: 6878; Percent complete: 98.3%; Average loss: 2.2969
# Iteration: 6879; Percent complete: 98.3%; Average loss: 2.1287
# Iteration: 6880; Percent complete: 98.3%; Average loss: 2.1806
# Iteration: 6881; Percent complete: 98.3%; Average loss: 1.9596
# Iteration: 6882; Percent complete: 98.3%; Average loss: 2.1752
# Iteration: 6883; Percent complete: 98.3%; Average loss: 2.1858
# Iteration: 6884; Percent complete: 98.3%; Average loss: 1.9091
# Iteration: 6885; Percent complete: 98.4%; Average loss: 1.9698
# Iteration: 6886; Percent complete: 98.4%; Average loss: 2.0305
# Iteration: 6887; Percent complete: 98.4%; Average loss: 1.9737
# Iteration: 6888; Percent complete: 98.4%; Average loss: 2.0299
# Iteration: 6889; Percent complete: 98.4%; Average loss: 1.9796
# Iteration: 6890; Percent complete: 98.4%; Average loss: 1.7520
# Iteration: 6891; Percent complete: 98.4%; Average loss: 2.0506
# Iteration: 6892; Percent complete: 98.5%; Average loss: 2.0940
# Iteration: 6893; Percent complete: 98.5%; Average loss: 2.0959
# Iteration: 6894; Percent complete: 98.5%; Average loss: 2.1801
# Iteration: 6895; Percent complete: 98.5%; Average loss: 1.8719
# Iteration: 6896; Percent complete: 98.5%; Average loss: 2.1206
# Iteration: 6897; Percent complete: 98.5%; Average loss: 2.0733
# Iteration: 6898; Percent complete: 98.5%; Average loss: 1.9492
# Iteration: 6899; Percent complete: 98.6%; Average loss: 2.1683
# Iteration: 6900; Percent complete: 98.6%; Average loss: 2.0852
# Iteration: 6901; Percent complete: 98.6%; Average loss: 1.7715
# Iteration: 6902; Percent complete: 98.6%; Average loss: 1.9881
# Iteration: 6903; Percent complete: 98.6%; Average loss: 2.0871
# Iteration: 6904; Percent complete: 98.6%; Average loss: 1.9848
# Iteration: 6905; Percent complete: 98.6%; Average loss: 2.1012
# Iteration: 6906; Percent complete: 98.7%; Average loss: 2.1963
# Iteration: 6907; Percent complete: 98.7%; Average loss: 1.8013
# Iteration: 6908; Percent complete: 98.7%; Average loss: 1.9919
# Iteration: 6909; Percent complete: 98.7%; Average loss: 1.9769
# Iteration: 6910; Percent complete: 98.7%; Average loss: 1.9237
# Iteration: 6911; Percent complete: 98.7%; Average loss: 2.2440
# Iteration: 6912; Percent complete: 98.7%; Average loss: 2.0681
# Iteration: 6913; Percent complete: 98.8%; Average loss: 2.0822
# Iteration: 6914; Percent complete: 98.8%; Average loss: 1.9632
# Iteration: 6915; Percent complete: 98.8%; Average loss: 2.0871
# Iteration: 6916; Percent complete: 98.8%; Average loss: 1.8309
# Iteration: 6917; Percent complete: 98.8%; Average loss: 1.9854
# Iteration: 6918; Percent complete: 98.8%; Average loss: 2.1472
# Iteration: 6919; Percent complete: 98.8%; Average loss: 2.0661
# Iteration: 6920; Percent complete: 98.9%; Average loss: 1.9891
# Iteration: 6921; Percent complete: 98.9%; Average loss: 2.0015
# Iteration: 6922; Percent complete: 98.9%; Average loss: 1.8273
# Iteration: 6923; Percent complete: 98.9%; Average loss: 1.9317
# Iteration: 6924; Percent complete: 98.9%; Average loss: 1.9948
# Iteration: 6925; Percent complete: 98.9%; Average loss: 2.0153
# Iteration: 6926; Percent complete: 98.9%; Average loss: 2.0705
# Iteration: 6927; Percent complete: 99.0%; Average loss: 1.9700
# Iteration: 6928; Percent complete: 99.0%; Average loss: 2.0916
# Iteration: 6929; Percent complete: 99.0%; Average loss: 2.0470
# Iteration: 6930; Percent complete: 99.0%; Average loss: 2.0116
# Iteration: 6931; Percent complete: 99.0%; Average loss: 2.0136
# Iteration: 6932; Percent complete: 99.0%; Average loss: 1.9899
# Iteration: 6933; Percent complete: 99.0%; Average loss: 2.1394
# Iteration: 6934; Percent complete: 99.1%; Average loss: 2.1495
# Iteration: 6935; Percent complete: 99.1%; Average loss: 2.1153
# Iteration: 6936; Percent complete: 99.1%; Average loss: 1.9312
# Iteration: 6937; Percent complete: 99.1%; Average loss: 1.9288
# Iteration: 6938; Percent complete: 99.1%; Average loss: 2.1418
# Iteration: 6939; Percent complete: 99.1%; Average loss: 1.9865
# Iteration: 6940; Percent complete: 99.1%; Average loss: 2.0151
# Iteration: 6941; Percent complete: 99.2%; Average loss: 1.9361
# Iteration: 6942; Percent complete: 99.2%; Average loss: 2.1100
# Iteration: 6943; Percent complete: 99.2%; Average loss: 2.0525
# Iteration: 6944; Percent complete: 99.2%; Average loss: 2.1301
# Iteration: 6945; Percent complete: 99.2%; Average loss: 2.1429
# Iteration: 6946; Percent complete: 99.2%; Average loss: 1.9288
# Iteration: 6947; Percent complete: 99.2%; Average loss: 2.0980
# Iteration: 6948; Percent complete: 99.3%; Average loss: 2.0162
# Iteration: 6949; Percent complete: 99.3%; Average loss: 2.0009
# Iteration: 6950; Percent complete: 99.3%; Average loss: 2.0114
# Iteration: 6951; Percent complete: 99.3%; Average loss: 1.8921
# Iteration: 6952; Percent complete: 99.3%; Average loss: 2.2393
# Iteration: 6953; Percent complete: 99.3%; Average loss: 1.8594
# Iteration: 6954; Percent complete: 99.3%; Average loss: 2.0879
# Iteration: 6955; Percent complete: 99.4%; Average loss: 1.9972
# Iteration: 6956; Percent complete: 99.4%; Average loss: 2.0857
# Iteration: 6957; Percent complete: 99.4%; Average loss: 2.0019
# Iteration: 6958; Percent complete: 99.4%; Average loss: 2.1295
# Iteration: 6959; Percent complete: 99.4%; Average loss: 1.9264
# Iteration: 6960; Percent complete: 99.4%; Average loss: 1.9208
# Iteration: 6961; Percent complete: 99.4%; Average loss: 1.9471
# Iteration: 6962; Percent complete: 99.5%; Average loss: 1.9204
# Iteration: 6963; Percent complete: 99.5%; Average loss: 2.2964
# Iteration: 6964; Percent complete: 99.5%; Average loss: 1.9650
# Iteration: 6965; Percent complete: 99.5%; Average loss: 1.9455
# Iteration: 6966; Percent complete: 99.5%; Average loss: 2.0332
# Iteration: 6967; Percent complete: 99.5%; Average loss: 1.9400
# Iteration: 6968; Percent complete: 99.5%; Average loss: 1.9980
# Iteration: 6969; Percent complete: 99.6%; Average loss: 2.2203
# Iteration: 6970; Percent complete: 99.6%; Average loss: 2.0875
# Iteration: 6971; Percent complete: 99.6%; Average loss: 1.9584
# Iteration: 6972; Percent complete: 99.6%; Average loss: 1.9985
# Iteration: 6973; Percent complete: 99.6%; Average loss: 2.1250
# Iteration: 6974; Percent complete: 99.6%; Average loss: 1.9651
# Iteration: 6975; Percent complete: 99.6%; Average loss: 2.1134
# Iteration: 6976; Percent complete: 99.7%; Average loss: 2.0170
# Iteration: 6977; Percent complete: 99.7%; Average loss: 2.0942
# Iteration: 6978; Percent complete: 99.7%; Average loss: 1.9584
# Iteration: 6979; Percent complete: 99.7%; Average loss: 1.9816
# Iteration: 6980; Percent complete: 99.7%; Average loss: 2.0993
# Iteration: 6981; Percent complete: 99.7%; Average loss: 2.0238
# Iteration: 6982; Percent complete: 99.7%; Average loss: 2.0804
# Iteration: 6983; Percent complete: 99.8%; Average loss: 1.9318
# Iteration: 6984; Percent complete: 99.8%; Average loss: 2.0236
# Iteration: 6985; Percent complete: 99.8%; Average loss: 1.9016
# Iteration: 6986; Percent complete: 99.8%; Average loss: 1.9583
# Iteration: 6987; Percent complete: 99.8%; Average loss: 2.1556
# Iteration: 6988; Percent complete: 99.8%; Average loss: 1.9582
# Iteration: 6989; Percent complete: 99.8%; Average loss: 2.1824
# Iteration: 6990; Percent complete: 99.9%; Average loss: 1.8307
# Iteration: 6991; Percent complete: 99.9%; Average loss: 1.8147
# Iteration: 6992; Percent complete: 99.9%; Average loss: 2.0071
# Iteration: 6993; Percent complete: 99.9%; Average loss: 1.8902
# Iteration: 6994; Percent complete: 99.9%; Average loss: 1.9708
# Iteration: 6995; Percent complete: 99.9%; Average loss: 1.7930
# Iteration: 6996; Percent complete: 99.9%; Average loss: 2.0152
# Iteration: 6997; Percent complete: 100.0%; Average loss: 1.9494
# Iteration: 6998; Percent complete: 100.0%; Average loss: 2.1473
# Iteration: 6999; Percent complete: 100.0%; Average loss: 2.0692
# Iteration: 7000; Percent complete: 100.0%; Average loss: 2.1393

# %% [markdown]
# Run Evaluation
# ~~~~~~~~~~~~~~
#
# To chat with your model, run the following block.

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hi
# Bot: hi .
# > Hello
# Bot: hello .
# > Good morning
# Bot: good night .
# > good night
# Bot: good night .
# > good afternon
# Error: Encountered unknown word.
# > good afternoon
# Bot: you re a mutant .
# > What is your name?
# Bot: a videotape .
# > name
# Bot: xxxxxx
# > What's your name?
# Bot: a videotape .
# > How are you?
# Bot: i m fine .
# > How is going?
# Bot: i don t know .
# > q

# %%
from os import listdir
from os.path import isfile, join

# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
# evaluateInput(encoder, decoder, searcher, voc)

def loadSenstences(file):
    lines = open(file, encoding='utf-8').read().strip().split('\n')
    return lines

test_file_name = "test_data_10.csv"
test_csv = os.path.join("/content/drive/My Drive/Colab Notebooks/chatbot/data", test_file_name)
sentences = loadSenstences(test_csv)
loadFilename = None

print(sentences)
for checkpoint_iter in range(5000, 7000 + 1, 1000):
  
  loadFilename = os.path.join(save_dir, model_name, corpus_name,
                          '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
                          '{}_checkpoint.tar'.format(checkpoint_iter))
  
  # Load model if a loadFilename is provided
  if loadFilename:
      # If loading on same machine the model was trained on
      checkpoint = torch.load(loadFilename)
      # If loading a model trained on GPU to CPU
      # checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
      encoder_sd = checkpoint['en']
      decoder_sd = checkpoint['de']
      encoder_optimizer_sd = checkpoint['en_opt']
      decoder_optimizer_sd = checkpoint['de_opt']
      embedding_sd = checkpoint['embedding']
      voc.__dict__ = checkpoint['voc_dict']

  print('Building encoder and decoder ...')
  # Initialize word embeddings
  weights = torch.FloatTensor(model.wv.vectors)
  embedding = nn.Embedding.from_pretrained(weights)
  embedding = nn.Embedding(weights.shape[0], hidden_size)
  if loadFilename:
      embedding.load_state_dict(embedding_sd)
  # Initialize encoder & decoder models
  encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
  decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, weights.shape[0], decoder_n_layers, dropout)
  
  if loadFilename:
      encoder.load_state_dict(encoder_sd)
      decoder.load_state_dict(decoder_sd)

  # Use appropriate device
  encoder = encoder.to(device)
  decoder = decoder.to(device)

  print('Models built and ready to go!')

  eva_dir = os.path.join(save_evaluation, "word2Vec_model/")
  filedName = str(checkpoint_iter) + ".csv"
  saveFileName = os.path.join(eva_dir, filedName)
  if not os.path.exists(eva_dir):
    os.makedirs(eva_dir)

  QA = []
  for sentence in sentences:
    qa = {}
    print("================= {} =================", checkpoint_iter)
    sentence = normalizeString(sentence)
    # Initialize search module
    searcher = GreedySearchDecoder(encoder, decoder)

    print(">>>>> Input: ", sentence)
    output_words = evaluate(encoder, decoder, searcher, voc, sentence)
    output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
    output_words = ' '.join(output_words)
    print("<<<<< Output: ", output_words)
    
    qa['Question'] = sentence
    qa['Answer'] = output_words
    # qa['Loss'] = avg_loss
    QA.append(qa)

    with open(saveFileName, 'w', newline='') as csvfile:
        fieldnames = ['Question', 'Answer']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()   
        writer.writerows(QA)
# Out:
# ['Hi', 'Hey', 'Hey man', 'Yo', 'Good morning', 'Good afternoon', 'How are you?', 'How are you doing?', 'How is going?', 'What is up?', 'What is going on?', 'Good to see you', 'nice to see you', 'How have you been', 'Good to see you', 'Nice to meet you', 'Pleased to meet you', "What's your name?", 'How old are you?', "What's your age?", 'Where do you live?', 'Where are you from?', 'Where did you grow up?']
# Building encoder and decoder ...
# Models built and ready to go!
# ================= {} ================= 5000
# >>>>> Input:  hi
# <<<<< Output:  hi .
# ================= {} ================= 5000
# >>>>> Input:  hey
# <<<<< Output:  what ?
# ================= {} ================= 5000
# >>>>> Input:  hey man
# <<<<< Output:  hey .
# ================= {} ================= 5000
# >>>>> Input:  yo
# <<<<< Output:  what ?
# ================= {} ================= 5000
# >>>>> Input:  good morning
# <<<<< Output:  good morning .
# ================= {} ================= 5000
# >>>>> Input:  good afternoon
# <<<<< Output:  you re breaking on
# ================= {} ================= 5000
# >>>>> Input:  how are you ?
# <<<<< Output:  i m fine .
# ================= {} ================= 5000
# >>>>> Input:  how are you doing ?
# <<<<< Output:  i m fine .
# ================= {} ================= 5000
# >>>>> Input:  how is going ?
# <<<<< Output:  i don t know .
# ================= {} ================= 5000
# >>>>> Input:  what is up ?
# <<<<< Output:  i don t know .
# ================= {} ================= 5000
# >>>>> Input:  what is going on ?
# <<<<< Output:  i don t know .
# ================= {} ================= 5000
# >>>>> Input:  good to see you
# <<<<< Output:  good night .
# ================= {} ================= 5000
# >>>>> Input:  nice to see you
# <<<<< Output:  what ?
# ================= {} ================= 5000
# >>>>> Input:  how have you been
# <<<<< Output:  i m not sure .
# ================= {} ================= 5000
# >>>>> Input:  good to see you
# <<<<< Output:  good night .
# ================= {} ================= 5000
# >>>>> Input:  nice to meet you
# <<<<< Output:  what ?
# ================= {} ================= 5000
# >>>>> Input:  pleased to meet you
# <<<<< Output:  what ?
# ================= {} ================= 5000
# >>>>> Input:  what s your name ?
# <<<<< Output:  claire .
# ================= {} ================= 5000
# >>>>> Input:  how old are you ?
# <<<<< Output:  twenty eight .
# ================= {} ================= 5000
# >>>>> Input:  what s your age ?
# <<<<< Output:  i m not crying .
# ================= {} ================= 5000
# >>>>> Input:  where do you live ?
# <<<<< Output:  i m in the bathroom .
# ================= {} ================= 5000
# >>>>> Input:  where are you from ?
# <<<<< Output:  i m here .
# ================= {} ================= 5000
# >>>>> Input:  where did you grow up ?
# <<<<< Output:  i m not going to talk .
# Building encoder and decoder ...
# Models built and ready to go!
# ================= {} ================= 6000
# >>>>> Input:  hi
# <<<<< Output:  hi .
# ================= {} ================= 6000
# >>>>> Input:  hey
# <<<<< Output:  what ?
# ================= {} ================= 6000
# >>>>> Input:  hey man
# <<<<< Output:  what ?
# ================= {} ================= 6000
# >>>>> Input:  yo
# <<<<< Output:  what ?
# ================= {} ================= 6000
# >>>>> Input:  good morning
# <<<<< Output:  good night .
# ================= {} ================= 6000
# >>>>> Input:  good afternoon
# <<<<< Output:  you re not crazy .
# ================= {} ================= 6000
# >>>>> Input:  how are you ?
# <<<<< Output:  fine .
# ================= {} ================= 6000
# >>>>> Input:  how are you doing ?
# <<<<< Output:  i m fine .
# ================= {} ================= 6000
# >>>>> Input:  how is going ?
# <<<<< Output:  i don t know .
# ================= {} ================= 6000
# >>>>> Input:  what is up ?
# <<<<< Output:  i m not sure .
# ================= {} ================= 6000
# >>>>> Input:  what is going on ?
# <<<<< Output:  i don t know .
# ================= {} ================= 6000
# >>>>> Input:  good to see you
# <<<<< Output:  i m sorry .
# ================= {} ================= 6000
# >>>>> Input:  nice to see you
# <<<<< Output:  i m not sure .
# ================= {} ================= 6000
# >>>>> Input:  how have you been
# <<<<< Output:  good .
# ================= {} ================= 6000
# >>>>> Input:  good to see you
# <<<<< Output:  i m sorry .
# ================= {} ================= 6000
# >>>>> Input:  nice to meet you
# <<<<< Output:  i m sorry .
# ================= {} ================= 6000
# >>>>> Input:  pleased to meet you
# <<<<< Output:  i m sorry .
# ================= {} ================= 6000
# >>>>> Input:  what s your name ?
# <<<<< Output:  claire .
# ================= {} ================= 6000
# >>>>> Input:  how old are you ?
# <<<<< Output:  older .
# ================= {} ================= 6000
# >>>>> Input:  what s your age ?
# <<<<< Output:  i m not sure .
# ================= {} ================= 6000
# >>>>> Input:  where do you live ?
# <<<<< Output:  i m going home .
# ================= {} ================= 6000
# >>>>> Input:  where are you from ?
# <<<<< Output:  i m here .
# ================= {} ================= 6000
# >>>>> Input:  where did you grow up ?
# <<<<< Output:  i m going home .
# Building encoder and decoder ...
# Models built and ready to go!
# ================= {} ================= 7000
# >>>>> Input:  hi
# <<<<< Output:  hi .
# ================= {} ================= 7000
# >>>>> Input:  hey
# <<<<< Output:  hey .
# ================= {} ================= 7000
# >>>>> Input:  hey man
# <<<<< Output:  hey .
# ================= {} ================= 7000
# >>>>> Input:  yo
# <<<<< Output:  what ?
# ================= {} ================= 7000
# >>>>> Input:  good morning
# <<<<< Output:  good night .
# ================= {} ================= 7000
# >>>>> Input:  good afternoon
# <<<<< Output:  i ll get it .
# ================= {} ================= 7000
# >>>>> Input:  how are you ?
# <<<<< Output:  fine .
# ================= {} ================= 7000
# >>>>> Input:  how are you doing ?
# <<<<< Output:  i m fine .
# ================= {} ================= 7000
# >>>>> Input:  how is going ?
# <<<<< Output:  i don t know .
# ================= {} ================= 7000
# >>>>> Input:  what is up ?
# <<<<< Output:  i don t know .
# ================= {} ================= 7000
# >>>>> Input:  what is going on ?
# <<<<< Output:  i don t know .
# ================= {} ================= 7000
# >>>>> Input:  good to see you
# <<<<< Output:  i ll see you again randall
# ================= {} ================= 7000
# >>>>> Input:  nice to see you
# <<<<< Output:  i m sorry .
# ================= {} ================= 7000
# >>>>> Input:  how have you been
# <<<<< Output:  i m sorry i m sorry .
# ================= {} ================= 7000
# >>>>> Input:  good to see you
# <<<<< Output:  i ll see you again randall
# ================= {} ================= 7000
# >>>>> Input:  nice to meet you
# <<<<< Output:  i ll see you again randall
# ================= {} ================= 7000
# >>>>> Input:  pleased to meet you
# <<<<< Output:  pleasure to meet you .
# ================= {} ================= 7000
# >>>>> Input:  what s your name ?
# <<<<< Output:  victor frankenstein .
# ================= {} ================= 7000
# >>>>> Input:  how old are you ?
# <<<<< Output:  i don t know .
# ================= {} ================= 7000
# >>>>> Input:  what s your age ?
# <<<<< Output:  i don t know .
# ================= {} ================= 7000
# >>>>> Input:  where do you live ?
# <<<<< Output:  i don t know .
# ================= {} ================= 7000
# >>>>> Input:  where are you from ?
# <<<<< Output:  i don t know .
# ================= {} ================= 7000
# >>>>> Input:  where did you grow up ?
# <<<<< Output:  i don t know .

# %% [markdown]
# Conclusion
# ----------
#
# That’s all for this one, folks. Congratulations, you now know the
# fundamentals to building a generative chatbot model! If you’re
# interested, you can try tailoring the chatbot’s behavior by tweaking the
# model and training parameters and customizing the data that you train
# the model on.
#
# Check out the other tutorials for more cool deep learning applications
# in PyTorch!
